# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 5: Summaries of Groups of Data
#
# So far you've learned how to select, reformat, manipulate, order, and summarize data from a single table in database.  In this lesson, you are going to learn how to summarize multiple subsets of your data in the same query.  The method for doing this is to include a "GROUP BY" clause in your SQL query.
#
#
#
# ## The GROUP BY clause
#
# The GROUP BY clause comes after the WHERE clause, but before ORDER BY or LIMIT:
#
# <img src="https://duke.box.com/shared/static/lc0yjfz1339q3mc04ne13m2q5tkzy3x7.jpg" width=400 alt="SELECT FROM WHERE ORDER BY" />
#
# The GROUP BY clause is easy to incorporate into your queries.  In fact, it might be a little too easy to incorporate into MySQL queries, because it can be used incorrectly in MySQL queries even when no error message is displayed.  As a consequence, I suggest you adopt a healthy dose of caution every time you use the GROUP BY clause.  By the end of this lesson, you will understand why.  When used correctly, though, GROUP BY is one of the most useful and efficient parts of an SQL query, and once you are comfortable using it, you will use it very frequently.
#
# **To get started, load the SQL library and the Dognition database, and set the dognition database as the default:**

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# %sql USE dognitiondb
# Out:
# 0 rows affected.
# []

# %% [markdown]
# Let's return to a question from MySQL Exercise 4.  How would you query the average rating for each of the 40 tests in the Reviews table? As we discussed, one very inefficient method to do that would be to write 40 separate queries with each one having a different test name in the WHERE conditional clause.  Then you could copy or transcribe the results from all 40 queries into one place.  But that wouldn't be very pleasant.  Here's how you could do the same thing using one query that has a GROUP BY clause:
#
# ```mySQL
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# ```
#
# This query will output the average rating for each test.  More technically, this query will instruct MySQL to average all the rows that have the same value in the test_name column.
#
# Notice that I included test_name in the SELECT statement.  As a strong rule of thumb, if you are grouping by a column, you should also include that column in the SELECT statement.  If you don't do this, you won't know to which group each row of your output corresponds.
#
# **To see what I mean, try the query above without test_name included in the SELECT statement:**

# %%
# %%sql
# SELECT test_name,AVG(rating) AS avg_rating
# FROM reviews
# GROUP BY test_name
# Out:
# 40 rows affected.
# [('1 vs 1 Game', Decimal('3.9206')),
#  ('3 vs 1 Game', Decimal('4.2857')),
#  ('5 vs 1 Game', Decimal('3.9272')),
#  ('Arm Pointing', Decimal('4.2153')),
#  ('Cover Your Eyes', Decimal('2.6741')),
#  ('Delayed Cup Game', Decimal('3.3514')),
#  ('Different Perspective', Decimal('2.7647')),
#  ('Expression Game', Decimal('4.0000')),
#  ('Eye Contact Game', Decimal('2.9372')),
#  ('Eye Contact Warm-up', Decimal('0.9632')),
#  ('Foot Pointing', Decimal('4.0093')),
#  ('Impossible Task Game', Decimal('3.0965')),
#  ('Impossible Task Warm-up', Decimal('0.2174')),
#  ('Inferential Reasoning Game', Decimal('4.5223')),
#  ('Inferential Reasoning Warm-up', Decimal('4.3066')),
#  ('Memory versus Pointing', Decimal('3.5584')),
#  ('Memory versus Smell', Decimal('4.2623')),
#  ('Navigation Game', Decimal('2.9841')),
#  ('Navigation Learning', Decimal('2.0303')),
#  ('Navigation Warm-up', Decimal('1.9805')),
#  ('Numerosity Warm-Up', Decimal('2.6173')),
#  ('One Cup Warm-up', Decimal('1.3693')),
#  ('Physical Reasoning Game', Decimal('3.8492')),
#  ('Physical Reasoning Warm-up', Decimal('1.6625')),
#  ('Self Control Game', Decimal('3.8519')),
#  ('Shaker Game', Decimal('4.6667')),
#  ('Shaker Warm-Up', Decimal('2.1818')),
#  ('Shared Perspective', Decimal('3.2778')),
#  ('Slide', Decimal('4.5111')),
#  ('Smell Game', Decimal('4.2857')),
#  ('Stair Game', Decimal('4.2857')),
#  ('Switch', Decimal('5.5676')),
#  ('Treat Warm-up', Decimal('0.7909')),
#  ('Turn Your Back', Decimal('3.1293')),
#  ('Two Cup Warm-up', Decimal('1.6737')),
#  ('Warm-Up', Decimal('1.2020')),
#  ('Watching', Decimal('2.4594')),
#  ('Watching - Part 2', Decimal('2.6570')),
#  ('Yawn Game', Decimal('2.8477')),
#  ('Yawn Warm-up', Decimal('2.0035'))]

# %% [markdown]
# You can form groups using derived values as well as original columns.  To illustrate this, let's address another question: how many tests were completed during each month of the year?
#
# To answer this question, we need to take advantage of another datetime function described in the website below:
#
# http://www.w3resource.com/mysql/date-and-time-functions/date-and-time-functions.php
#
# MONTH() will return a number representing the month of a date entry. To get the total number of tests completed each month, you could put the MONTH function into the GROUP BY clause, in this case through an alias:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# ```
#
# You can also group by multiple columns or derived fields.  If we wanted to determine the total number of each type of test completed each month, you could include both "test_name" and the derived "Month" field in the GROUP BY clause, separated by a comma.
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month;
# ```
#
# MySQL allows you to use aliases in a GROUP BY clause, but some database systems do not.  If you are using a database system that does NOT accept aliases in GROUP BY clauses, you can still group by derived fields, but you have to duplicate the calculation for the derived field in the GROUP BY clause in addition to including the derived field in the SELECT clause:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at);
# ```
#
# Try the query once with test_name first in the GROUP BY list, and once with Month first in the GROUP BY list below.  Inspect the outputs:

# %%
# %%sql
# SELECT test_name,MONTH(created_at) AS month,COUNT(created_at) AS num_completed_tests
# FROM complete_tests
# GROUP BY test_name,month;
# Out:
# 480 rows affected.
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('3 vs 1 Game', 1, 35),
#  ('5 vs 1 Game', 1, 59),
#  ('Arm Pointing', 1, 622),
#  ('Cover Your Eyes', 1, 452),
#  ('Delayed Cup Game', 1, 356),
#  ('Different Perspective', 1, 2),
#  ('Expression Game', 1, 6),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Foot Pointing', 1, 506),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Smell', 1, 465),
#  ('Navigation Game', 1, 57),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Warm-up', 1, 62),
#  ('Numerosity Warm-Up', 1, 36),
#  ('One Cup Warm-up', 1, 476),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Self Control Game', 1, 8),
#  ('Shaker Game', 1, 2),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shared Perspective', 1, 1),
#  ('Slide', 1, 17),
#  ('Smell Game', 1, 13),
#  ('Stair Game', 1, 12),
#  ('Switch', 1, 15),
#  ('Treat Warm-up', 1, 626),
#  ('Turn Your Back', 1, 462),
#  ('Two Cup Warm-up', 1, 490),
#  ('Warm-up', 1, 70),
#  ('Watching', 1, 594),
#  ('Watching - Part 2', 1, 445),
#  ('Yawn Game', 1, 828),
#  ('Yawn Warm-up', 1, 834),
#  ('1 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 2, 28),
#  ('5 vs 1 Game', 2, 54),
#  ('Arm Pointing', 2, 498),
#  ('Cover Your Eyes', 2, 373),
#  ('Delayed Cup Game', 2, 319),
#  ('Different Perspective', 2, 3),
#  ('Expression Game', 2, 9),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Foot Pointing', 2, 433),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Smell', 2, 374),
#  ('Navigation Game', 2, 41),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Warm-up', 2, 43),
#  ('Numerosity Warm-Up', 2, 28),
#  ('One Cup Warm-up', 2, 388),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Self Control Game', 2, 8),
#  ('Shaker Game', 2, 9),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shared Perspective', 2, 3),
#  ('Slide', 2, 12),
#  ('Smell Game', 2, 18),
#  ('Stair Game', 2, 8),
#  ('Switch', 2, 12),
#  ('Treat Warm-up', 2, 495),
#  ('Turn Your Back', 2, 372),
#  ('Two Cup Warm-up', 2, 386),
#  ('Warm-up', 2, 77),
#  ('Watching', 2, 443),
#  ('Watching - Part 2', 2, 372),
#  ('Yawn Game', 2, 709),
#  ('Yawn Warm-up', 2, 712),
#  ('1 vs 1 Game', 3, 22),
#  ('3 vs 1 Game', 3, 34),
#  ('5 vs 1 Game', 3, 57),
#  ('Arm Pointing', 3, 507),
#  ('Cover Your Eyes', 3, 416),
#  ('Delayed Cup Game', 3, 350),
#  ('Different Perspective', 3, 4),
#  ('Expression Game', 3, 12),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Foot Pointing', 3, 477),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Smell', 3, 382),
#  ('Navigation Game', 3, 47),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Warm-up', 3, 50),
#  ('Numerosity Warm-Up', 3, 35),
#  ('One Cup Warm-up', 3, 388),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Self Control Game', 3, 11),
#  ('Shaker Game', 3, 8),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shared Perspective', 3, 3),
#  ('Slide', 3, 16),
#  ('Smell Game', 3, 16),
#  ('Stair Game', 3, 7),
#  ('Switch', 3, 14),
#  ('Treat Warm-up', 3, 515),
#  ('Turn Your Back', 3, 418),
#  ('Two Cup Warm-up', 3, 389),
#  ('Warm-Up', 3, 79),
#  ('Watching', 3, 472),
#  ('Watching - Part 2', 3, 406),
#  ('Yawn Game', 3, 681),
#  ('Yawn Warm-up', 3, 698),
#  ('1 vs 1 Game', 4, 12),
#  ('3 vs 1 Game', 4, 16),
#  ('5 vs 1 Game', 4, 29),
#  ('Arm Pointing', 4, 381),
#  ('Cover Your Eyes', 4, 291),
#  ('Delayed Cup Game', 4, 256),
#  ('Different Perspective', 4, 8),
#  ('Expression Game', 4, 10),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Foot Pointing', 4, 339),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Smell', 4, 280),
#  ('Navigation Game', 4, 41),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Warm-up', 4, 42),
#  ('Numerosity Warm-Up', 4, 17),
#  ('One Cup Warm-up', 4, 313),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Self Control Game', 4, 9),
#  ('Shaker Game', 4, 4),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shared Perspective', 4, 8),
#  ('Slide', 4, 11),
#  ('Smell Game', 4, 6),
#  ('Stair Game', 4, 4),
#  ('Switch', 4, 11),
#  ('Treat Warm-up', 4, 393),
#  ('Turn Your Back', 4, 298),
#  ('Two Cup Warm-up', 4, 308),
#  ('Warm-Up', 4, 54),
#  ('Watching', 4, 322),
#  ('Watching - Part 2', 4, 282),
#  ('Yawn Game', 4, 525),
#  ('Yawn Warm-up', 4, 541),
#  ('1 vs 1 Game', 5, 13),
#  ('3 vs 1 Game', 5, 34),
#  ('5 vs 1 Game', 5, 50),
#  ('Arm Pointing', 5, 1149),
#  ('Cover Your Eyes', 5, 753),
#  ('Delayed Cup Game', 5, 539),
#  ('Different Perspective', 5, 12),
#  ('Expression Game', 5, 9),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Foot Pointing', 5, 926),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Smell', 5, 667),
#  ('Navigation Game', 5, 336),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Warm-up', 5, 625),
#  ('Numerosity Warm-Up', 5, 37),
#  ('One Cup Warm-up', 5, 757),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Self Control Game', 5, 9),
#  ('Shaker Game', 5, 10),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shared Perspective', 5, 11),
#  ('Slide', 5, 17),
#  ('Smell Game', 5, 19),
#  ('Stair Game', 5, 10),
#  ('Switch', 5, 15),
#  ('Treat Warm-up', 5, 1182),
#  ('Turn Your Back', 5, 769),
#  ('Two Cup Warm-up', 5, 747),
#  ('Warm-Up', 5, 71),
#  ('Watching', 5, 980),
#  ('Watching - Part 2', 5, 734),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Warm-up', 5, 2143),
#  ('1 vs 1 Game', 6, 18),
#  ('3 vs 1 Game', 6, 42),
#  ('5 vs 1 Game', 6, 61),
#  ('Arm Pointing', 6, 1424),
#  ('Cover Your Eyes', 6, 767),
#  ('Delayed Cup Game', 6, 525),
#  ('Different Perspective', 6, 11),
#  ('Expression Game', 6, 11),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Foot Pointing', 6, 1125),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Smell', 6, 666),
#  ('Navigation Game', 6, 81),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Warm-up', 6, 114),
#  ('Numerosity Warm-Up', 6, 44),
#  ('One Cup Warm-up', 6, 745),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Self Control Game', 6, 11),
#  ('Shaker Game', 6, 7),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shared Perspective', 6, 11),
#  ('Slide', 6, 10),
#  ('Smell Game', 6, 9),
#  ('Stair Game', 6, 7),
#  ('Switch', 6, 11),
#  ('Treat Warm-up', 6, 1444),
#  ('Turn Your Back', 6, 778),
#  ('Two Cup Warm-up', 6, 732),
#  ('Warm-Up', 6, 64),
#  ('Watching', 6, 1035),
#  ('Watching - Part 2', 6, 747),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Warm-up', 6, 3071),
#  ('1 vs 1 Game', 7, 36),
#  ('3 vs 1 Game', 7, 37),
#  ('5 vs 1 Game', 7, 69),
#  ('Arm Pointing', 7, 913),
#  ('Cover Your Eyes', 7, 521),
#  ('Delayed Cup Game', 7, 407),
#  ('Different Perspective', 7, 8),
#  ('Expression Game', 7, 12),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Foot Pointing', 7, 759),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Smell', 7, 491),
#  ('Navigation Game', 7, 70),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Warm-up', 7, 88),
#  ('Numerosity Warm-Up', 7, 37),
#  ('One Cup Warm-up', 7, 536),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Self Control Game', 7, 14),
#  ('Shaker Game', 7, 5),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shared Perspective', 7, 7),
#  ('Slide', 7, 13),
#  ('Smell Game', 7, 21),
#  ('Stair Game', 7, 14),
#  ('Switch', 7, 11),
#  ('Treat Warm-up', 7, 951),
#  ('Turn Your Back', 7, 535),
#  ('Two Cup Warm-up', 7, 537),
#  ('Warm-Up', 7, 101),
#  ('Watching', 7, 679),
#  ('Watching - Part 2', 7, 504),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Warm-up', 7, 1909),
#  ('1 vs 1 Game', 8, 17),
#  ('3 vs 1 Game', 8, 23),
#  ('5 vs 1 Game', 8, 38),
#  ('Arm Pointing', 8, 779),
#  ('Cover Your Eyes', 8, 408),
#  ('Delayed Cup Game', 8, 355),
#  ('Different Perspective', 8, 10),
#  ('Expression Game', 8, 11),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Foot Pointing', 8, 653),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Smell', 8, 402),
#  ('Navigation Game', 8, 41),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Warm-up', 8, 40),
#  ('Numerosity Warm-Up', 8, 23),
#  ('One Cup Warm-up', 8, 416),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Self Control Game', 8, 13),
#  ('Shaker Game', 8, 6),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shared Perspective', 8, 10),
#  ('Slide', 8, 6),
#  ('Smell Game', 8, 10),
#  ('Stair Game', 8, 15),
#  ('Switch', 8, 10),
#  ('Treat Warm-up', 8, 791),
#  ('Turn Your Back', 8, 418),
#  ('Two Cup Warm-up', 8, 419),
#  ('Warm-Up', 8, 64),
#  ('Watching', 8, 511),
#  ('Watching - Part 2', 8, 405),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Warm-up', 8, 1694),
#  ('1 vs 1 Game', 9, 28),
#  ('3 vs 1 Game', 9, 24),
#  ('5 vs 1 Game', 9, 50),
#  ('Arm Pointing', 9, 1243),
#  ('Cover Your Eyes', 9, 574),
#  ('Delayed Cup Game', 9, 424),
#  ('Different Perspective', 9, 12),
#  ('Expression Game', 9, 17),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Foot Pointing', 9, 992),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Smell', 9, 529),
#  ('Navigation Game', 9, 52),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Warm-up', 9, 58),
#  ('Numerosity Warm-Up', 9, 24),
#  ('One Cup Warm-up', 9, 602),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Self Control Game', 9, 19),
#  ('Shaker Game', 9, 12),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shared Perspective', 9, 12),
#  ('Slide', 9, 18),
#  ('Smell Game', 9, 16),
#  ('Stair Game', 9, 17),
#  ('Switch', 9, 13),
#  ('Treat Warm-up', 9, 1303),
#  ('Turn Your Back', 9, 599),
#  ('Two Cup Warm-up', 9, 578),
#  ('Warm-Up', 9, 103),
#  ('Watching', 9, 809),
#  ('Watching - Part 2', 9, 568),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Warm-up', 9, 2771),
#  ('1 vs 1 Game', 10, 27),
#  ('3 vs 1 Game', 10, 28),
#  ('5 vs 1 Game', 10, 54),
#  ('Arm Pointing', 10, 2535),
#  ('Cover Your Eyes', 10, 1653),
#  ('Delayed Cup Game', 10, 1019),
#  ('Different Perspective', 10, 4),
#  ('Expression Game', 10, 3),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Foot Pointing', 10, 2290),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Smell', 10, 1111),
#  ('Navigation Game', 10, 69),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Warm-up', 10, 76),
#  ('Numerosity Warm-Up', 10, 29),
#  ('One Cup Warm-up', 10, 1272),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Self Control Game', 10, 9),
#  ('Shaker Game', 10, 10),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shared Perspective', 10, 4),
#  ('Slide', 10, 7),
#  ('Smell Game', 10, 15),
#  ('Stair Game', 10, 7),
#  ('Switch', 10, 9),
#  ('Treat Warm-up', 10, 2626),
#  ('Turn Your Back', 10, 1711),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Warm-up', 10, 69),
#  ('Watching', 10, 1797),
#  ('Watching - Part 2', 10, 1578),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Warm-up', 10, 4387),
#  ('1 vs 1 Game', 11, 15),
#  ('3 vs 1 Game', 11, 22),
#  ('5 vs 1 Game', 11, 40),
#  ('Arm Pointing', 11, 735),
#  ('Cover Your Eyes', 11, 595),
#  ('Delayed Cup Game', 11, 422),
#  ('Different Perspective', 11, 6),
#  ('Expression Game', 11, 11),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Foot Pointing', 11, 685),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Smell', 11, 444),
#  ('Navigation Game', 11, 47),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Warm-up', 11, 52),
#  ('Numerosity Warm-Up', 11, 26),
#  ('One Cup Warm-up', 11, 491),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Self Control Game', 11, 15),
#  ('Shaker Game', 11, 3),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shared Perspective', 11, 6),
#  ('Slide', 11, 13),
#  ('Smell Game', 11, 12),
#  ('Stair Game', 11, 3),
#  ('Switch', 11, 10),
#  ('Treat Warm-up', 11, 744),
#  ('Turn Your Back', 11, 601),
#  ('Two Cup Warm-up', 11, 482),
#  ('Warm-Up', 11, 65),
#  ('Watching', 11, 611),
#  ('Watching - Part 2', 11, 565),
#  ('Yawn Game', 11, 989),
#  ('Yawn Warm-up', 11, 1060),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 12, 7),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 12, 8),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 12, 56),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 12, 1043)]

# %%
# %%sql
# SELECT test_name,MONTH(created_at) AS month,COUNT(created_at) AS num_completed_tests
# FROM complete_tests
# GROUP BY month,test_name;
# Out:
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('3 vs 1 Game', 1, 35),
#  ('5 vs 1 Game', 1, 59),
#  ('Arm Pointing', 1, 622),
#  ('Cover Your Eyes', 1, 452),
#  ('Delayed Cup Game', 1, 356),
#  ('Different Perspective', 1, 2),
#  ('Expression Game', 1, 6),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Foot Pointing', 1, 506),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Smell', 1, 465),
#  ('Navigation Game', 1, 57),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Warm-up', 1, 62),
#  ('Numerosity Warm-Up', 1, 36),
#  ('One Cup Warm-up', 1, 476),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Self Control Game', 1, 8),
#  ('Shaker Game', 1, 2),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shared Perspective', 1, 1),
#  ('Slide', 1, 17),
#  ('Smell Game', 1, 13),
#  ('Stair Game', 1, 12),
#  ('Switch', 1, 15),
#  ('Treat Warm-up', 1, 626),
#  ('Turn Your Back', 1, 462),
#  ('Two Cup Warm-up', 1, 490),
#  ('Warm-up', 1, 70),
#  ('Watching', 1, 594),
#  ('Watching - Part 2', 1, 445),
#  ('Yawn Game', 1, 828),
#  ('Yawn Warm-up', 1, 834),
#  ('1 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 2, 28),
#  ('5 vs 1 Game', 2, 54),
#  ('Arm Pointing', 2, 498),
#  ('Cover Your Eyes', 2, 373),
#  ('Delayed Cup Game', 2, 319),
#  ('Different Perspective', 2, 3),
#  ('Expression Game', 2, 9),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Foot Pointing', 2, 433),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Smell', 2, 374),
#  ('Navigation Game', 2, 41),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Warm-up', 2, 43),
#  ('Numerosity Warm-Up', 2, 28),
#  ('One Cup Warm-up', 2, 388),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Self Control Game', 2, 8),
#  ('Shaker Game', 2, 9),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shared Perspective', 2, 3),
#  ('Slide', 2, 12),
#  ('Smell Game', 2, 18),
#  ('Stair Game', 2, 8),
#  ('Switch', 2, 12),
#  ('Treat Warm-up', 2, 495),
#  ('Turn Your Back', 2, 372),
#  ('Two Cup Warm-up', 2, 386),
#  ('Warm-up', 2, 77),
#  ('Watching', 2, 443),
#  ('Watching - Part 2', 2, 372),
#  ('Yawn Game', 2, 709),
#  ('Yawn Warm-up', 2, 712),
#  ('1 vs 1 Game', 3, 22),
#  ('3 vs 1 Game', 3, 34),
#  ('5 vs 1 Game', 3, 57),
#  ('Arm Pointing', 3, 507),
#  ('Cover Your Eyes', 3, 416),
#  ('Delayed Cup Game', 3, 350),
#  ('Different Perspective', 3, 4),
#  ('Expression Game', 3, 12),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Foot Pointing', 3, 477),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Smell', 3, 382),
#  ('Navigation Game', 3, 47),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Warm-up', 3, 50),
#  ('Numerosity Warm-Up', 3, 35),
#  ('One Cup Warm-up', 3, 388),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Self Control Game', 3, 11),
#  ('Shaker Game', 3, 8),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shared Perspective', 3, 3),
#  ('Slide', 3, 16),
#  ('Smell Game', 3, 16),
#  ('Stair Game', 3, 7),
#  ('Switch', 3, 14),
#  ('Treat Warm-up', 3, 515),
#  ('Turn Your Back', 3, 418),
#  ('Two Cup Warm-up', 3, 389),
#  ('Warm-Up', 3, 79),
#  ('Watching', 3, 472),
#  ('Watching - Part 2', 3, 406),
#  ('Yawn Game', 3, 681),
#  ('Yawn Warm-up', 3, 698),
#  ('1 vs 1 Game', 4, 12),
#  ('3 vs 1 Game', 4, 16),
#  ('5 vs 1 Game', 4, 29),
#  ('Arm Pointing', 4, 381),
#  ('Cover Your Eyes', 4, 291),
#  ('Delayed Cup Game', 4, 256),
#  ('Different Perspective', 4, 8),
#  ('Expression Game', 4, 10),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Foot Pointing', 4, 339),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Smell', 4, 280),
#  ('Navigation Game', 4, 41),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Warm-up', 4, 42),
#  ('Numerosity Warm-Up', 4, 17),
#  ('One Cup Warm-up', 4, 313),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Self Control Game', 4, 9),
#  ('Shaker Game', 4, 4),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shared Perspective', 4, 8),
#  ('Slide', 4, 11),
#  ('Smell Game', 4, 6),
#  ('Stair Game', 4, 4),
#  ('Switch', 4, 11),
#  ('Treat Warm-up', 4, 393),
#  ('Turn Your Back', 4, 298),
#  ('Two Cup Warm-up', 4, 308),
#  ('Warm-Up', 4, 54),
#  ('Watching', 4, 322),
#  ('Watching - Part 2', 4, 282),
#  ('Yawn Game', 4, 525),
#  ('Yawn Warm-up', 4, 541),
#  ('1 vs 1 Game', 5, 13),
#  ('3 vs 1 Game', 5, 34),
#  ('5 vs 1 Game', 5, 50),
#  ('Arm Pointing', 5, 1149),
#  ('Cover Your Eyes', 5, 753),
#  ('Delayed Cup Game', 5, 539),
#  ('Different Perspective', 5, 12),
#  ('Expression Game', 5, 9),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Foot Pointing', 5, 926),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Smell', 5, 667),
#  ('Navigation Game', 5, 336),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Warm-up', 5, 625),
#  ('Numerosity Warm-Up', 5, 37),
#  ('One Cup Warm-up', 5, 757),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Self Control Game', 5, 9),
#  ('Shaker Game', 5, 10),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shared Perspective', 5, 11),
#  ('Slide', 5, 17),
#  ('Smell Game', 5, 19),
#  ('Stair Game', 5, 10),
#  ('Switch', 5, 15),
#  ('Treat Warm-up', 5, 1182),
#  ('Turn Your Back', 5, 769),
#  ('Two Cup Warm-up', 5, 747),
#  ('Warm-Up', 5, 71),
#  ('Watching', 5, 980),
#  ('Watching - Part 2', 5, 734),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Warm-up', 5, 2143),
#  ('1 vs 1 Game', 6, 18),
#  ('3 vs 1 Game', 6, 42),
#  ('5 vs 1 Game', 6, 61),
#  ('Arm Pointing', 6, 1424),
#  ('Cover Your Eyes', 6, 767),
#  ('Delayed Cup Game', 6, 525),
#  ('Different Perspective', 6, 11),
#  ('Expression Game', 6, 11),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Foot Pointing', 6, 1125),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Smell', 6, 666),
#  ('Navigation Game', 6, 81),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Warm-up', 6, 114),
#  ('Numerosity Warm-Up', 6, 44),
#  ('One Cup Warm-up', 6, 745),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Self Control Game', 6, 11),
#  ('Shaker Game', 6, 7),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shared Perspective', 6, 11),
#  ('Slide', 6, 10),
#  ('Smell Game', 6, 9),
#  ('Stair Game', 6, 7),
#  ('Switch', 6, 11),
#  ('Treat Warm-up', 6, 1444),
#  ('Turn Your Back', 6, 778),
#  ('Two Cup Warm-up', 6, 732),
#  ('Warm-Up', 6, 64),
#  ('Watching', 6, 1035),
#  ('Watching - Part 2', 6, 747),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Warm-up', 6, 3071),
#  ('1 vs 1 Game', 7, 36),
#  ('3 vs 1 Game', 7, 37),
#  ('5 vs 1 Game', 7, 69),
#  ('Arm Pointing', 7, 913),
#  ('Cover Your Eyes', 7, 521),
#  ('Delayed Cup Game', 7, 407),
#  ('Different Perspective', 7, 8),
#  ('Expression Game', 7, 12),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Foot Pointing', 7, 759),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Smell', 7, 491),
#  ('Navigation Game', 7, 70),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Warm-up', 7, 88),
#  ('Numerosity Warm-Up', 7, 37),
#  ('One Cup Warm-up', 7, 536),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Self Control Game', 7, 14),
#  ('Shaker Game', 7, 5),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shared Perspective', 7, 7),
#  ('Slide', 7, 13),
#  ('Smell Game', 7, 21),
#  ('Stair Game', 7, 14),
#  ('Switch', 7, 11),
#  ('Treat Warm-up', 7, 951),
#  ('Turn Your Back', 7, 535),
#  ('Two Cup Warm-up', 7, 537),
#  ('Warm-Up', 7, 101),
#  ('Watching', 7, 679),
#  ('Watching - Part 2', 7, 504),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Warm-up', 7, 1909),
#  ('1 vs 1 Game', 8, 17),
#  ('3 vs 1 Game', 8, 23),
#  ('5 vs 1 Game', 8, 38),
#  ('Arm Pointing', 8, 779),
#  ('Cover Your Eyes', 8, 408),
#  ('Delayed Cup Game', 8, 355),
#  ('Different Perspective', 8, 10),
#  ('Expression Game', 8, 11),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Foot Pointing', 8, 653),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Smell', 8, 402),
#  ('Navigation Game', 8, 41),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Warm-up', 8, 40),
#  ('Numerosity Warm-Up', 8, 23),
#  ('One Cup Warm-up', 8, 416),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Self Control Game', 8, 13),
#  ('Shaker Game', 8, 6),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shared Perspective', 8, 10),
#  ('Slide', 8, 6),
#  ('Smell Game', 8, 10),
#  ('Stair Game', 8, 15),
#  ('Switch', 8, 10),
#  ('Treat Warm-up', 8, 791),
#  ('Turn Your Back', 8, 418),
#  ('Two Cup Warm-up', 8, 419),
#  ('Warm-Up', 8, 64),
#  ('Watching', 8, 511),
#  ('Watching - Part 2', 8, 405),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Warm-up', 8, 1694),
#  ('1 vs 1 Game', 9, 28),
#  ('3 vs 1 Game', 9, 24),
#  ('5 vs 1 Game', 9, 50),
#  ('Arm Pointing', 9, 1243),
#  ('Cover Your Eyes', 9, 574),
#  ('Delayed Cup Game', 9, 424),
#  ('Different Perspective', 9, 12),
#  ('Expression Game', 9, 17),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Foot Pointing', 9, 992),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Smell', 9, 529),
#  ('Navigation Game', 9, 52),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Warm-up', 9, 58),
#  ('Numerosity Warm-Up', 9, 24),
#  ('One Cup Warm-up', 9, 602),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Self Control Game', 9, 19),
#  ('Shaker Game', 9, 12),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shared Perspective', 9, 12),
#  ('Slide', 9, 18),
#  ('Smell Game', 9, 16),
#  ('Stair Game', 9, 17),
#  ('Switch', 9, 13),
#  ('Treat Warm-up', 9, 1303),
#  ('Turn Your Back', 9, 599),
#  ('Two Cup Warm-up', 9, 578),
#  ('Warm-Up', 9, 103),
#  ('Watching', 9, 809),
#  ('Watching - Part 2', 9, 568),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Warm-up', 9, 2771),
#  ('1 vs 1 Game', 10, 27),
#  ('3 vs 1 Game', 10, 28),
#  ('5 vs 1 Game', 10, 54),
#  ('Arm Pointing', 10, 2535),
#  ('Cover Your Eyes', 10, 1653),
#  ('Delayed Cup Game', 10, 1019),
#  ('Different Perspective', 10, 4),
#  ('Expression Game', 10, 3),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Foot Pointing', 10, 2290),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Smell', 10, 1111),
#  ('Navigation Game', 10, 69),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Warm-up', 10, 76),
#  ('Numerosity Warm-Up', 10, 29),
#  ('One Cup Warm-up', 10, 1272),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Self Control Game', 10, 9),
#  ('Shaker Game', 10, 10),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shared Perspective', 10, 4),
#  ('Slide', 10, 7),
#  ('Smell Game', 10, 15),
#  ('Stair Game', 10, 7),
#  ('Switch', 10, 9),
#  ('Treat Warm-up', 10, 2626),
#  ('Turn Your Back', 10, 1711),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Warm-up', 10, 69),
#  ('Watching', 10, 1797),
#  ('Watching - Part 2', 10, 1578),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Warm-up', 10, 4387),
#  ('1 vs 1 Game', 11, 15),
#  ('3 vs 1 Game', 11, 22),
#  ('5 vs 1 Game', 11, 40),
#  ('Arm Pointing', 11, 735),
#  ('Cover Your Eyes', 11, 595),
#  ('Delayed Cup Game', 11, 422),
#  ('Different Perspective', 11, 6),
#  ('Expression Game', 11, 11),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Foot Pointing', 11, 685),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Smell', 11, 444),
#  ('Navigation Game', 11, 47),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Warm-up', 11, 52),
#  ('Numerosity Warm-Up', 11, 26),
#  ('One Cup Warm-up', 11, 491),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Self Control Game', 11, 15),
#  ('Shaker Game', 11, 3),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shared Perspective', 11, 6),
#  ('Slide', 11, 13),
#  ('Smell Game', 11, 12),
#  ('Stair Game', 11, 3),
#  ('Switch', 11, 10),
#  ('Treat Warm-up', 11, 744),
#  ('Turn Your Back', 11, 601),
#  ('Two Cup Warm-up', 11, 482),
#  ('Warm-Up', 11, 65),
#  ('Watching', 11, 611),
#  ('Watching - Part 2', 11, 565),
#  ('Yawn Game', 11, 989),
#  ('Yawn Warm-up', 11, 1060),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 12, 7),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 12, 8),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 12, 56),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 12, 1043)]

# %% [markdown]
# Notice that in the first case, the first block of rows share the same test_name, but are broken up into separate months (for those of you who took the "Data Visualization and Communication with Tableau" course of this specialization, this is similar to what would happen if you put test_name first and created_at second on the rows or columns shelf in Tableau).
#
# In the second case, the first block of rows share the same month, but are broken up into separate tests  (this is similar to what would happen if you put created_at first and test_name second on the rows or columns shelf in Tableau).  If you were to visualize these outputs, they would look like the charts below.
#
# <img src="https://duke.box.com/shared/static/y6l3ldxg289brid5mmn886qweglt65qv.jpg" width=800 alt="ORDER" />
#
# Different database servers might default to ordering the outputs in a certain way, but you shouldn't rely on that being the case.  To ensure the output is ordered in a way you intend, add an ORDER BY clause to your grouped query using the syntax you already know and have practiced:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month
# ORDER BY test_name ASC, Month ASC;
# ```
#
# **Question 1: Output a table that calculates the number of distinct female and male dogs in each breed group of the Dogs table, sorted by the total number of dogs in descending order (the sex/breed_group pair with the greatest number of dogs should have 8466 unique Dog_Guids):**

# %%
# %%sql
# SELECT gender,breed,COUNT(DISTINCT dog_guid) AS num_dogs
# FROM dogs
# GROUP BY gender,breed
# ORDER BY num_dogs DESC;
# Out:
# 2719 rows affected.
# [('female', 'Mixed', 4079),
#  ('male', 'Mixed', 3923),
#  ('male', 'Labrador Retriever', 1139),
#  ('female', 'Labrador Retriever', 1067),
#  ('male', 'Golden Retriever', 715),
#  ('female', 'Golden Retriever', 581),
#  ('male', 'German Shepherd Dog', 533),
#  ('female', 'German Shepherd Dog', 507),
#  ('male', "I Don't Know", 492),
#  ('female', "I Don't Know", 487),
#  ('male', 'Poodle', 378),
#  ('female', 'Border Collie', 328),
#  ('male', 'Shih Tzu', 328),
#  ('male', 'Border Collie', 316),
#  ('male', 'Australian Shepherd', 314),
#  ('female', 'Australian Shepherd', 310),
#  ('female', 'Poodle', 304),
#  ('male', 'Other', 260),
#  ('female', 'Other', 258),
#  ('male', 'Golden Doodle', 237),
#  ('male', 'Dachshund', 237),
#  ('male', 'Boxer', 237),
#  ('female', 'Golden Doodle', 209),
#  ('female', 'Dachshund', 207),
#  ('female', 'Chihuahua', 204),
#  ('female', 'Shih Tzu', 194),
#  ('female', 'Boxer', 189),
#  ('male', 'Miniature Schnauzer', 189),
#  ('male', 'Chihuahua', 185),
#  ('male', 'Yorkshire Terrier', 180),
#  ('male', 'Labradoodle', 178),
#  ('female', 'American Pit Bull Terrier', 172),
#  ('female', 'Labradoodle', 167),
#  ('male', 'Beagle', 161),
#  ('male', 'American Pit Bull Terrier', 158),
#  ('female', 'Miniature Schnauzer', 151),
#  ('female', 'Beagle', 151),
#  ('male', 'Pug', 144),
#  ('male', 'Shetland Sheepdog', 143),
#  ('female', 'Yorkshire Terrier', 143),
#  ('female', 'Labrador Retriever-Golden Retriever Mix', 135),
#  ('male', 'Doberman Pinscher', 135),
#  ('male', 'Boston Terrier', 124),
#  ('male', 'Cocker Spaniel', 124),
#  ('male', 'Labrador Retriever-Golden Retriever Mix', 119),
#  ('male', 'English Springer Spaniel', 116),
#  ('male', 'Siberian Husky', 114),
#  ('male', 'French Bulldog', 107),
#  ('male', 'Bulldog', 106),
#  ('male', 'Maltese', 105),
#  ('male', 'Cavalier King Charles Spaniel', 104),
#  ('male', 'Cockapoo', 103),
#  ('female', 'Boston Terrier', 103),
#  ('female', 'Shetland Sheepdog', 102),
#  ('male', 'Havanese', 101),
#  ('female', 'Bulldog', 100),
#  ('male', 'Rottweiler', 98),
#  ('female', 'Cocker Spaniel', 97),
#  ('male', 'West Highland White Terrier', 94),
#  ('female', 'Cavalier King Charles Spaniel', 93),
#  ('male', 'Pomeranian', 92),
#  ('male', 'Golden Retriever-Labrador Retriever Mix', 90),
#  ('male', 'Bichon Frise', 89),
#  ('female', 'Maltese', 89),
#  ('female', 'Doberman Pinscher', 89),
#  ('female', 'French Bulldog', 88),
#  ('female', 'Rottweiler', 88),
#  ('female', 'Siberian Husky', 87),
#  ('male', 'Pembroke Welsh Corgi', 87),
#  ('female', 'Pug', 87),
#  ('male', 'Australian Cattle Dog', 87),
#  ('female', 'English Springer Spaniel', 85),
#  ('female', 'Australian Cattle Dog', 82),
#  ('female', 'Pembroke Welsh Corgi', 82),
#  ('female', 'Havanese', 80),
#  ('female', 'West Highland White Terrier', 80),
#  ('male', 'Jack Russell Terrier', 79),
#  ('male', 'Parson Russell Terrier', 79),
#  ('female', 'Parson Russell Terrier', 79),
#  ('female', 'Bichon Frise', 77),
#  ('female', 'Great Dane', 76),
#  ('female', 'Golden Retriever-Labrador Retriever Mix', 72),
#  ('female', 'Cockapoo', 71),
#  ('male', 'Vizsla', 71),
#  ('male', 'Weimaraner', 70),
#  ('female', 'Pomeranian', 70),
#  ('female', 'Soft Coated Wheaten Terrier', 68),
#  ('male', 'Rhodesian Ridgeback', 67),
#  ('male', 'Great Dane', 65),
#  ('female', 'Weimaraner', 65),
#  ('male', 'Portuguese Water Dog', 63),
#  ('female', 'Jack Russell Terrier', 63),
#  ('female', 'Vizsla', 59),
#  ('male', 'Greyhound', 59),
#  ('male', 'Russell Terrier', 58),
#  ('male', 'American Staffordshire Terrier', 58),
#  ('male', 'Standard Poodle', 58),
#  ('female', 'Rat Terrier', 56),
#  ('male', 'Shiba Inu', 56),
#  ('male', 'German Shorthaired Pointer', 56),
#  ('male', 'Basset Hound', 55),
#  ('female', 'Miniature Pinscher', 54),
#  ('male', 'Soft Coated Wheaten Terrier', 54),
#  ('male', 'Papillon', 54),
#  ('female', 'Rhodesian Ridgeback', 53),
#  ('female', 'American Staffordshire Terrier', 52),
#  ('female', 'Russell Terrier', 52),
#  ('female', 'Belgian Malinois', 51),
#  ('male', 'Miniature Pinscher', 51),
#  ('male', 'Collie', 50),
#  ('female', 'Portuguese Water Dog', 50),
#  ('female', 'Bernese Mountain Dog', 50),
#  ('male', 'Rat Terrier', 49),
#  ('male', 'Brittany', 49),
#  ('male', 'Bernese Mountain Dog', 48),
#  ('female', 'Collie', 48),
#  ('female', 'Basset Hound', 48),
#  ('male', 'Cairn Terrier', 47),
#  ('male', 'Border Terrier', 47),
#  ('female', 'Shiba Inu', 47),
#  ('male', 'Belgian Malinois', 45),
#  ('female', 'Maltese-Poodle Mix', 45),
#  ('female', 'German Shorthaired Pointer', 45),
#  ('female', 'English Cocker Spaniel', 44),
#  ('female', 'Brittany', 44),
#  ('female', 'Papillon', 43),
#  ('male', 'Maltese-Poodle Mix', 43),
#  ('male', 'Puggle', 43),
#  ('male', 'Whippet', 42),
#  ('female', 'Standard Poodle', 41),
#  ('male', 'Flat-Coated Retriever', 41),
#  ('female', 'Puggle', 39),
#  ('male', 'Staffordshire Bull Terrier', 39),
#  ('female', 'Greyhound', 39),
#  ('female', 'Staffordshire Bull Terrier', 37),
#  ('female', 'Border Collie-Labrador Retriever Mix', 37),
#  ('female', 'Australian Labradoodle', 36),
#  ('male', 'English Cocker Spaniel', 35),
#  ('male', 'Newfoundland', 35),
#  ('female', 'Cairn Terrier', 35),
#  ('male', 'Coton de Tulear', 34),
#  ('female', 'Dalmatian', 33),
#  ('male', 'Standard Schnauzer', 32),
#  ('female', 'American Eskimo Dog', 32),
#  ('male', 'Great Pyrenees', 32),
#  ('female', 'Border Terrier', 32),
#  ('male', 'Labrador Retriever-German Shepherd Dog Mix', 31),
#  ('male', 'Dalmatian', 31),
#  ('male', 'Shih Tzu-Poodle Mix', 31),
#  ('male', 'American Eskimo Dog', 31),
#  ('female', 'Coton de Tulear', 31),
#  ('male', 'Yorkshire Terrier-Poodle Mix', 30),
#  ('male', 'Alaskan Malamute', 30),
#  ('male', 'Cocker Spaniel-Poodle Mix', 30),
#  ('female', 'Bouvier des Flandres', 29),
#  ('male', 'Miniature Schnauzer-Poodle Mix', 29),
#  ('female', 'Nova Scotia Duck Tolling Retriever', 29),
#  ('male', 'Australian Labradoodle', 29),
#  ('male', 'Nova Scotia Duck Tolling Retriever', 29),
#  ('male', 'Akita', 28),
#  ('female', 'Labrador Retriever-Border Collie Mix', 28),
#  ('female', 'Airedale Terrier', 28),
#  ('male', 'Airedale Terrier', 27),
#  ('male', 'Scottish Terrier', 27),
#  ('male', 'Border Collie-Australian Shepherd Mix', 26),
#  ('female', 'German Shepherd Dog-Labrador Retriever Mix', 26),
#  ('female', 'Belgian Tervuren', 26),
#  ('female', 'Whippet', 26),
#  ('male', 'Golden Retriever-Poodle Mix', 26),
#  ('male', 'Samoyed', 26),
#  ('female', 'Newfoundland', 25),
#  ('female', 'Flat-Coated Retriever', 25),
#  ('male', 'Lhasa Apso', 25),
#  ('male', 'Labrador Retriever-American Pit Bull Terrier Mix', 25),
#  ('male', 'Chihuahua-Dachshund Mix', 25),
#  ('female', 'Golden Retriever-Poodle Mix', 24),
#  ('female', 'Bull Terrier', 24),
#  ('male', 'Border Collie-Labrador Retriever Mix', 24),
#  ('female', 'Akita', 24),
#  ('female', 'Maltese-Yorkshire Terrier Mix', 24),
#  ('female', 'German Shepherd Dog-Siberian Husky Mix', 24),
#  ('male', 'Maltese-Yorkshire Terrier Mix', 23),
#  ('male', 'Brussels Griffon', 23),
#  ('female', 'Samoyed', 23),
#  ('male', 'Labrador Retriever-Border Collie Mix', 23),
#  ('female', 'Mastiff', 23),
#  ('female', 'Tibetan Terrier', 23),
#  ('male', 'Mastiff', 22),
#  ('female', 'Australian Shepherd-Border Collie Mix', 22),
#  ('female', 'Catahoula Leopard Dog', 22),
#  ('male', 'Bichon Frise-Poodle Mix', 22),
#  ('male', 'Australian Shepherd-Border Collie Mix', 22),
#  ('male', 'Italian Greyhound', 22),
#  ('male', 'St. Bernard', 21),
#  ('male', 'Bull Terrier', 21),
#  ('male', 'Miniature American Shepherd', 21),
#  ('female', 'Alaskan Malamute', 20),
#  ('female', 'Bearded Collie', 20),
#  ('female', 'Chinese Crested', 20),
#  ('female', 'Labrador Retriever-American Pit Bull Terrier Mix', 20),
#  ('female', 'Cardigan Welsh Corgi', 20),
#  ('female', 'Border Collie-Australian Shepherd Mix', 20),
#  ('male', 'German Shepherd Dog-Labrador Retriever Mix', 20),
#  ('female', 'Chihuahua-Dachshund Mix', 20),
#  ('female', 'Standard Schnauzer', 20),
#  ('male', 'English Setter', 19),
#  ('male', 'Cardigan Welsh Corgi', 19),
#  ('male', 'Silky Terrier', 19),
#  ('male', 'Old English Sheepdog', 19),
#  ('female', 'St. Bernard', 19),
#  ('female', 'Labrador Retriever-German Shepherd Dog Mix', 18),
#  ('female', 'Poodle-Miniature Schnauzer Mix', 18),
#  ('female', 'Border Collie-Australian Cattle Dog Mix', 18),
#  ('male', 'Labrador Retriever-Poodle Mix', 18),
#  ('male', 'Catahoula Leopard Dog', 18),
#  ('male', 'Chinese Crested', 18),
#  ('female', 'Italian Greyhound', 18),
#  ('female', 'Miniature Australian Shepherd', 17),
#  ('female', 'Poodle-Maltese Mix', 17),
#  ('female', 'Cane Corso', 17),
#  ('female', 'Bichon Frise-Poodle Mix', 17),
#  ('female', 'Cocker Spaniel-Poodle Mix', 17),
#  ('female', 'Shih Tzu-Poodle Mix', 17),
#  ('male', 'Bouvier des Flandres', 17),
#  ('male', 'Cane Corso', 17),
#  ('female', 'Scottish Terrier', 17),
#  ('male', 'Basenji', 17),
#  ('female', 'Miniature Schnauzer-Poodle Mix', 17),
#  ('male', 'Chinese Shar-Pei', 17),
#  ('female', 'Siberian Husky-German Shepherd Dog Mix', 17),
#  ('male', 'Shorkie', 17),
#  ('female', 'Australian Kelpie', 16),
#  ('female', 'Cavalier King Charles Spaniel-Poodle Mix', 16),
#  ('female', 'Miniature American Shepherd', 16),
#  ('female', 'Chesapeake Bay Retriever', 16),
#  ('male', 'Boxer-Labrador Retriever Mix', 16),
#  ('male', 'Border Collie-Australian Cattle Dog Mix', 16),
#  ('female', 'American Pit Bull Terrier-Labrador Retriever Mix', 16),
#  ('female', 'English Setter', 16),
#  ('male', 'Tibetan Terrier', 16),
#  ('female', 'Shorkie', 16),
#  ('female', 'Bullmastiff', 16),
#  ('male', 'American Pit Bull Terrier-Boxer Mix', 16),
#  ('male', 'Labrador Retriever-Rottweiler Mix', 16),
#  ('male', 'Poodle-Miniature Schnauzer Mix', 16),
#  ('male', 'Bichon Frise-Shih Tzu Mix', 16),
#  ('female', 'Yorkshire Terrier-Poodle Mix', 16),
#  ('male', 'German Wirehaired Pointer', 15),
#  ('male', 'Yorkshire Terrier-Maltese Mix', 15),
#  ('male', 'Chihuahua-Miniature Pinscher Mix', 15),
#  ('male', 'Cavalier King Charles Spaniel-Poodle Mix', 15),
#  ('male', 'Chesapeake Bay Retriever', 15),
#  ('male', 'Miniature Australian Shepherd', 15),
#  ('male', 'American Pit Bull Terrier-Labrador Retriever Mix', 15),
#  ('male', 'Poodle-Shih Tzu Mix', 15),
#  ('female', 'Lhasa Apso', 15),
#  ('female', 'Pekingese', 14),
#  ('male', 'Poodle-Yorkshire Terrier Mix', 14),
#  ('male', 'Chow Chow', 14),
#  ('male', 'Pekingese', 14),
#  ('male', 'Australian Terrier', 14),
#  ('female', 'Great Pyrenees', 14),
#  ('male', 'German Shepherd Dog-Siberian Husky Mix', 14),
#  ('female', 'Boxer-Labrador Retriever Mix', 14),
#  ('male', 'Wire Fox Terrier', 14),
#  ('male', 'Labrador Retriever-Weimaraner Mix', 14),
#  ('male', 'Keeshond', 14),
#  ('male', 'Dutch Shepherd', 13),
#  ('male', 'Australian Shepherd-Poodle Mix', 13),
#  ('female', 'Dachshund-Chihuahua Mix', 13),
#  ('female', 'Dutch Shepherd', 13),
#  ('male', 'Siberian Husky-German Shepherd Dog Mix', 13),
#  ('female', 'Australian Cattle Dog-Border Collie Mix', 13),
#  ('female', 'Labrador Retriever-Poodle Mix', 13),
#  ('male', 'Chihuahua-Rat Terrier Mix', 13),
#  ('female', 'Irish Setter', 13),
#  ('male', 'Irish Setter', 13),
#  ('female', 'Yorkshire Terrier-Maltese Mix', 13),
#  ('female', 'Australian Cattle Dog-Labrador Retriever Mix', 13),
#  ('female', 'Maltese-Shih Tzu Mix', 13),
#  ('male', 'Maltese-Shih Tzu Mix', 13),
#  ('male', 'Bullmastiff', 13),
#  ('female', 'Leonberger', 13),
#  ('male', 'Leonberger', 12),
#  ('female', 'Treeing Walker Coonhound', 12),
#  ('female', 'Chinese Shar-Pei', 12),
#  ('female', 'Old English Sheepdog', 12),
#  ('female', 'Welsh Terrier', 12),
#  ('male', 'Poodle-Maltese Mix', 12),
#  ('male', 'Chihuahua-Yorkshire Terrier Mix', 12),
#  ('male', 'Schipperke', 11),
#  ('male', 'Australian Shepherd-Labrador Retriever Mix', 11),
#  ('male', 'Bugg', 11),
#  ('female', 'American Pit Bull Terrier-Boxer Mix', 11),
#  ('male', 'German Shepherd Dog-Golden Retriever Mix', 11),
#  ('female', 'Silky Terrier', 11),
#  ('male', 'Beaglier', 11),
#  ('male', 'Bearded Collie', 11),
#  ('female', 'Bichon Frise-Shih Tzu Mix', 11),
#  ('female', 'Chow Chow', 11),
#  ('female', 'Greater Swiss Mountain Dog', 11),
#  ('female', 'Lagotto Romagnolo', 11),
#  ('female', 'Australian Shepherd-Poodle Mix', 11),
#  ('male', 'Poodle-Bichon Frise Mix', 10),
#  ('male', 'Australian Cattle Dog-Border Collie Mix', 10),
#  ('male', 'Welsh Springer Spaniel', 10),
#  ('female', 'Wire Fox Terrier', 10),
#  ('male', 'Welsh Terrier', 10),
#  ('male', 'Labrador Retriever- Mix', 10),
#  ('female', 'Lhasa Apso-Poodle Mix', 10),
#  ('female', 'Basenji', 10),
#  ('male', 'BullBoxer', 10),
#  ('male', 'American Staffordshire Terrier-American Pit Bull Terrier Mix', 10),
#  ('female', 'Poodle-Shih Tzu Mix', 10),
#  ('male', 'Pomapoo', 10),
#  ('male', 'American Pit Bull Terrier-American Staffordshire Terrier Mix', 10),
#  ('female', 'Welsh Springer Spaniel', 10),
#  ('female', 'Beagle-Labrador Retriever Mix', 10),
#  ('male', 'Norwich Terrier', 10),
#  ('male', 'Greater Swiss Mountain Dog', 10),
#  ('female', 'Border Collie-German Shepherd Dog Mix', 10),
#  ('male', 'Treeing Walker Coonhound', 10),
#  ('male', 'Belgian Sheepdog', 10),
#  ('female', 'Cavalier King Charles Spaniel-Bichon Frise Mix', 10),
#  ('male', 'Beagle-Labrador Retriever Mix', 10),
#  ('male', 'Lagotto Romagnolo', 10),
#  ('female', 'Shih Tzu-Bichon Frise Mix', 10),
#  ('male', 'Chihuahua-Jack Russell Terrier Mix', 9),
#  ('male', 'Rottweiler-Labrador Retriever Mix', 9),
#  ('male', 'Australian Cattle Dog-Australian Shepherd Mix', 9),
#  ('male', 'Cavalier King Charles Spaniel-Bichon Frise Mix', 9),
#  ('male', 'Giant Schnauzer', 9),
#  ('female', 'Chihuahua-Yorkshire Terrier Mix', 9),
#  ('female', 'Boxer-American Pit Bull Terrier Mix', 9),
#  ('female', 'German Spitz', 9),
#  ('female', 'Bichon Frise-Cavalier King Charles Spaniel Mix', 9),
#  ('female', 'German Wirehaired Pointer', 9),
#  ('male', 'Yorkshire Terrier-Miniature Schnauzer Mix', 9),
#  ('female', 'Australian Terrier', 9),
#  ('male', 'Pointer', 9),
#  ('female', 'BullBoxer', 9),
#  ('female', 'Shih Tzu-Maltese Mix', 9),
#  ('female', 'German Shepherd Dog-Chow Chow Mix', 9),
#  ('male', 'Chihuahua-Pomeranian Mix', 9),
#  ('female', 'Beagle-Dachshund Mix', 9),
#  ('female', 'Schipperke', 9),
#  ('male', 'Shih Tzu-Bichon Frise Mix', 9),
#  ('male', 'Tibetan Spaniel', 9),
#  ('male', 'Icelandic Sheepdog', 9),
#  ('female', 'Labrador Retriever-Boxer Mix', 9),
#  ('female', 'Irish Terrier', 9),
#  ('male', 'Affenpinscher', 9),
#  ('male', 'Labrador Retriever-Siberian Husky Mix', 9),
#  ('female', 'Labrador Retriever-Weimaraner Mix', 9),
#  ('female', 'Spanish Water Dog', 9),
#  ('female', 'Briard', 9),
#  ('male', 'Anatolian Shepherd Dog', 9),
#  ('female', 'Pointer', 9),
#  ('male', 'Belgian Tervuren', 9),
#  ('male', 'Spinone Italiano', 8),
#  ('female', 'American Pit Bull Terrier-American Staffordshire Terrier Mix', 8),
#  ('male', 'Bluetick Coonhound', 8),
#  ('female', 'Toy Fox Terrier', 8),
#  ('female', 'Pomapoo', 8),
#  ('female', 'Labrador Retriever- Mix', 8),
#  ('female', 'Canaan Dog', 8),
#  ('female', 'Giant Schnauzer', 8),
#  ('male', 'Poodle-Cocker Spaniel Mix', 8),
#  ('female', 'Labrador Retriever-Australian Shepherd Mix', 8),
#  ('male', 'Lhasa Apso-Shih Tzu Mix', 8),
#  ('male', 'Hovawart', 8),
#  ('female', 'Afghan Hound', 8),
#  ('male', 'Chihuahua-Pug Mix', 8),
#  ('male', 'Norfolk Terrier', 8),
#  ('male', 'German Shepherd Dog-Rottweiler Mix', 8),
#  ('male', 'Pomeranian-Chihuahua Mix', 8),
#  ('male', 'Alaskan Malamute-Siberian Husky Mix', 8),
#  ('male', 'Toy Fox Terrier', 8),
#  ('female', 'Chihuahua-Miniature Pinscher Mix', 8),
#  ('male', 'Irish Terrier', 8),
#  ('female', 'Redbone Coonhound', 8),
#  ('male', 'Briard', 8),
#  ('female', 'Border Collie-Golden Retriever Mix', 8),
#  ('male', 'Irish Wolfhound', 8),
#  ('female', 'Keeshond', 8),
#  ('male', 'Wirehaired Pointing Griffon', 8),
#  ('female', 'Chihuahua-Pomeranian Mix', 8),
#  ('male', 'Afghan Hound', 8),
#  ('male', 'Dogo Argentino', 8),
#  ('female', 'German Shepherd Dog-Australian Shepherd Mix', 8),
#  ('male', 'German Shepherd Dog-Border Collie Mix', 8),
#  ('female', 'American Staffordshire Terrier-American Pit Bull Terrier Mix', 8),
#  ('female', 'Chihuahua-Russell Terrier Mix', 8),
#  ('male', 'Border Collie-German Shepherd Dog Mix', 8),
#  ('female', 'Eurasier', 8),
#  ('male', 'Rottweiler-German Shepherd Dog Mix', 7),
#  ('male', 'Gordon Setter', 7),
#  ('female', 'American Staffordshire Terrier-Boxer Mix', 7),
#  ('male', 'Manchester Terrier', 7),
#  ('male', 'Kerry Blue Terrier', 7),
#  ('female', 'Jack Russell Terrier-Chihuahua Mix', 7),
#  ('male', 'Beagle-Russell Terrier Mix', 7),
#  ('female', 'Gordon Setter', 7),
#  ('female', 'Australian Cattle Dog-Australian Shepherd Mix', 7),
#  ('female', 'Bedlington Terrier', 7),
#  ('female', 'Border Collie-Siberian Husky Mix', 7),
#  ('female', 'Hovawart', 7),
#  ('female', 'Norwegian Elkhound', 7),
#  ('female', 'Norwich Terrier', 7),
#  ('male', 'Labrador Retriever-Great Dane Mix', 7),
#  ('female', 'Labrador Retriever-Beagle Mix', 7),
#  ('male', 'Bichon Frise-Cavalier King Charles Spaniel Mix', 7),
#  ('male', 'Beauceron', 7),
#  ('male', 'Labrador Retriever-Australian Shepherd Mix', 7),
#  ('male', 'Siberian Husky-Labrador Retriever Mix', 7),
#  ('male', 'Poodle-Golden Retriever Mix', 7),
#  ('female', 'Labrador Retriever-Rottweiler Mix', 7),
#  ('male', 'Poodle-Labrador Retriever Mix', 7),
#  ('male', 'Alaskan Malamute-German Shepherd Dog Mix', 7),
#  ('male', 'Boxer-American Pit Bull Terrier Mix', 7),
#  ('male', 'Golden Retriever-German Shepherd Dog Mix', 7),
#  ('female', 'Poodle-Bichon Frise Mix', 7),
#  ('male', 'Shih Tzu-Maltese Mix', 7),
#  ('male', 'Norwegian Elkhound', 7),
#  ('female', 'Australian Cattle Dog-German Shepherd Dog Mix', 7),
#  ('female', 'Catahoula Leopard Dog-Labrador Retriever Mix', 7),
#  ('male', 'Australian Shepherd-Australian Cattle Dog Mix', 7),
#  ('female', 'Irish Water Spaniel', 7),
#  ('female', 'Irish Wolfhound', 7),
#  ('female', 'German Shepherd Dog-Rottweiler Mix', 7),
#  ('male', 'Field Spaniel', 7),
#  ('female', 'Australian Shepherd-Labrador Retriever Mix', 7),
#  ('female', 'Chihuahua-Pug Mix', 7),
#  ('male', 'Bloodhound', 7),
#  ('male', 'Chihuahua-Italian Greyhound Mix', 6),
#  ('female', 'Poodle-Golden Retriever Mix', 6),
#  ('male', 'German Spitz', 6),
#  ('male', 'Border Collie-Golden Retriever Mix', 6),
#  ('male', 'Border Collie-Greyhound Mix', 6),
#  ('female', 'Beagle-Border Collie Mix', 6),
#  ('male', 'Poodle-Cavalier King Charles Spaniel Mix', 6),
#  ('female', 'Puli', 6),
#  ('female', 'Beauceron', 6),
#  ('female', 'Dogue de Bordeaux', 6),
#  ('male', 'Australian Cattle Dog-German Shepherd Dog Mix', 6),
#  ('male', 'Labrador Retriever-German Shorthaired Pointer Mix', 6),
#  ('female', 'Shih Tzu-Lhasa Apso Mix', 6),
#  ('male', '-Labrador Retriever Mix', 6),
#  ('female', 'Wirehaired Pointing Griffon', 6),
#  ('male', 'Neapolitan Mastiff', 6),
#  ('male', 'Redbone Coonhound', 6),
#  ('male', 'Labrador Retriever-Australian Cattle Dog Mix', 6),
#  ('male', 'German Shepherd Dog- Mix', 6),
#  ('female', 'Poodle-Yorkshire Terrier Mix', 6),
#  ('male', 'Czechoslovakian Vlcak', 6),
#  ('male', 'Australian Kelpie', 6),
#  ('female', 'German Shepherd Dog-Greyhound Mix', 6),
#  ('female', 'Rat Terrier-Chihuahua Mix', 6),
#  ('female', 'Shih Tzu-Yorkshire Terrier Mix', 6),
#  ('male', 'Border Collie-Siberian Husky Mix', 6),
#  ('male', 'Chihuahua-Russell Terrier Mix', 6),
#  ('female', 'Chihuahua-Jack Russell Terrier Mix', 6),
#  ('female', 'German Shepherd Dog- Mix', 6),
#  ('female', 'Labrador Retriever-Staffordshire Bull Terrier Mix', 6),
#  ('male', 'American Staffordshire Terrier-Labrador Retriever Mix', 6),
#  ('female', 'Black Russian Terrier', 6),
#  ('male', 'Boxer-American Staffordshire Terrier Mix', 6),
#  ('male', 'Dachshund-Chihuahua Mix', 6),
#  ('female', 'Golden Retriever-Border Collie Mix', 6),
#  ('female', 'Poodle-Cavalier King Charles Spaniel Mix', 6),
#  ('male', 'American Pit Bull Terrier-Bulldog Mix', 6),
#  ('male', 'Jack-A-Poo', 6),
#  ('female', 'Anatolian Shepherd Dog', 6),
#  ('male', 'Finnish Lapphund', 6),
#  ('male', 'Xoloitzcuintli', 6),
#  ('female', 'Labrador Retriever-Collie Mix', 6),
#  ('male', 'Labrador Retriever-Chow Chow Mix', 6),
#  ('male', 'German Shepherd Dog-Chow Chow Mix', 6),
#  ('female', 'Beaglier', 5),
#  ('female', '-Labrador Retriever Mix', 5),
#  ('female', 'Brussels Griffon', 5),
#  ('male', 'Borzoi', 5),
#  ('male', 'Poodle-Standard Schnauzer Mix', 5),
#  ('female', 'Siberian Husky-Labrador Retriever Mix', 5),
#  ('female', 'Australian Shepherd-Shetland Sheepdog Mix', 5),
#  ('female', 'Border Collie- Mix', 5),
#  ('female', 'Finnish Lapphund', 5),
#  ('female', 'Stabyhoun', 5),
#  ('male', 'Australian Shepherd-Golden Retriever Mix', 5),
#  ('female', 'Beagle-Bluetick Coonhound Mix', 5),
#  ('female', 'American Staffordshire Terrier-Bulldog Mix', 5),
#  ('male', 'Beagle-Pug Mix', 5),
#  ('male', 'Yorkshire Terrier-Chihuahua Mix', 5),
#  ('male', 'Boerboel', 5),
#  ('male', 'Rat Terrier-Chihuahua Mix', 5),
#  ('female', 'Labrador Retriever-Great Dane Mix', 5),
#  ('female', 'Pomeranian-Chihuahua Mix', 5),
#  ('female', 'Labrador Retriever-American Staffordshire Terrier Mix', 5),
#  ('male', 'Boston Terrier-French Bulldog Mix', 5),
#  ('male', 'Lhasa Apso-Poodle Mix', 5),
#  ('female', 'Norwegian Buhund', 5),
#  ('male', 'Chihuahua-Papillon Mix', 5),
#  ('male', 'German Pinscher', 5),
#  ('female', 'Australian Shepherd-Australian Cattle Dog Mix', 5),
#  ('male', 'Labrador Retriever-Greyhound Mix', 5),
#  ('female', 'German Shepherd Dog-Doberman Pinscher Mix', 5),
#  ('female', 'Jack-A-Poo', 5),
#  ('female', 'Small Munsterlander Pointer', 5),
#  ('male', 'Bedlington Terrier', 5),
#  ('male', 'Pug-Chihuahua Mix', 5),
#  ('male', 'German Shepherd Dog-Alaskan Malamute Mix', 5),
#  ('female', 'Smooth Fox Terrier', 5),
#  ('male', 'Clumber Spaniel', 5),
#  ('female', 'Boxer-German Shepherd Dog Mix', 5),
#  ('male', 'Pekingese-Poodle Mix', 5),
#  ('male', 'Labrador Retriever-Pointer Mix', 5),
#  ('female', 'Belgian Sheepdog', 5),
#  ('male', 'German Shepherd Dog-Australian Shepherd Mix', 5),
#  ('male', 'Boykin Spaniel', 5),
#  ('female', 'Rat Terrier-Russell Terrier Mix', 5),
#  ('female', 'Boykin Spaniel', 5),
#  ('female', 'Borzoi', 5),
#  ('female', 'American Foxhound', 5),
#  ('male', 'Pug-Shih Tzu Mix', 5),
#  ('female', 'Poodle-Cocker Spaniel Mix', 5),
#  ('male', 'Japanese Chin', 5),
#  ('male', 'German Shepherd Dog-Belgian Malinois Mix', 5),
#  ('male', 'Smooth Fox Terrier', 5),
#  ('female', 'Bluetick Coonhound', 5),
#  ('female', 'Golden Retriever-German Shepherd Dog Mix', 5),
#  ('female', 'Spinone Italiano', 5),
#  ('male', 'German Shorthaired Pointer-Labrador Retriever Mix', 5),
#  ('female', 'Labrador Retriever-Chow Chow Mix', 5),
#  ('male', 'Labrador Retriever-Chesapeake Bay Retriever Mix', 5),
#  ('male', 'Wirehaired Vizsla', 5),
#  ('female', 'Tibetan Spaniel', 5),
#  ('male', 'Border Collie-English Springer Spaniel Mix', 5),
#  ('male', 'Saluki', 5),
#  ('female', 'Boston Terrier-French Bulldog Mix', 5),
#  ('male', 'Dogue de Bordeaux', 5),
#  ('male', 'Dachshund-Labrador Retriever Mix', 5),
#  ('female', '-German Shepherd Dog Mix', 5),
#  ('female', 'Mudi', 5),
#  ('male', 'Poodle-Soft Coated Wheaten Terrier Mix', 5),
#  ('male', 'Lakeland Terrier', 5),
#  ('female', 'Kooikerhondje', 5),
#  ('male', 'Plott', 4),
#  ('male', '-Australian Cattle Dog Mix', 4),
#  ('male', 'Berger Picard', 4),
#  ('female', 'Field Spaniel', 4),
#  ('female', 'Labrador Retriever-English Springer Spaniel Mix', 4),
#  ('female', 'Beagle-Basset Hound Mix', 4),
#  ('male', 'Bullmastiff-Staffordshire Bull Terrier Mix', 4),
#  ('female', 'Labrador Retriever-German Shorthaired Pointer Mix', 4),
#  ('female', 'German Shorthaired Pointer-Labrador Retriever Mix', 4),
#  ('male', 'Chinook', 4),
#  ('female', 'Border Collie-American Pit Bull Terrier Mix', 4),
#  ('male', 'Glen of Imaal Terrier', 4),
#  ('female', 'German Shepherd Dog-Boxer Mix', 4),
#  ('male', 'Siberian Husky-Australian Shepherd Mix', 4),
#  ('female', 'Dogo Argentino', 4),
#  ('female', 'Miniature Pinscher-Chihuahua Mix', 4),
#  ('female', 'Labrador Retriever-Australian Cattle Dog Mix', 4),
#  ('female', 'Pyrenean Shepherd', 4),
#  ('male', 'American Staffordshire Terrier- Mix', 4),
#  ('male', 'Dachshund-Yorkshire Terrier Mix', 4),
#  ('male', 'Chow Chow-Labrador Retriever Mix', 4),
#  ('male', 'Havanese-Poodle Mix', 4),
#  ('male', 'Swedish Vallhund', 4),
#  ('female', 'Affenpinscher', 4),
#  ('male', 'Great Dane-Labrador Retriever Mix', 4),
#  ('male', 'American Staffordshire Terrier-Border Collie Mix', 4),
#  ('male', 'Yorkshire Terrier-Shih Tzu Mix', 4),
#  ('male', 'Pug-Beagle Mix', 4),
#  ('female', 'Pekingese-Shih Tzu Mix', 4),
#  ('female', 'Boxer-Bulldog Mix', 4),
#  ('female', 'Shih Tzu-Pekingese Mix', 4),
#  ('male', 'Poodle-English Springer Spaniel Mix', 4),
#  ('female', 'Bichon Frise-Yorkshire Terrier Mix', 4),
#  ('male', 'Border Collie-Australian Kelpie Mix', 4),
#  ('female', 'Xoloitzcuintli', 4),
#  ('female', 'Pomeranian-Yorkshire Terrier Mix', 4),
#  ('female', 'Black and Tan Coonhound', 4),
#  ('female', 'Rottweiler-American Pit Bull Terrier Mix', 4),
#  ('female', 'Labrador Retriever-Black and Tan Coonhound Mix', 4),
#  ('male', 'Labrador Retriever-Mastiff Mix', 4),
#  ('female', 'American Staffordshire Terrier-Labrador Retriever Mix', 4),
#  ('male', 'German Shepherd Dog-Poodle Mix', 4),
#  ('female', 'Yorkshire Terrier-Bichon Frise Mix', 4),
#  ('male', 'Chesapeake Bay Retriever-Labrador Retriever Mix', 4),
#  ('male', 'Golden Retriever-Chow Chow Mix', 4),
#  ('male', 'Jack Russell Terrier-Rat Terrier Mix', 4),
#  ('male', 'German Shepherd Dog-American Pit Bull Terrier Mix', 4),
#  ('female', 'Yorkshire Terrier-Chihuahua Mix', 4),
#  ('male', 'Labrador Retriever-Beagle Mix', 4),
#  ('male', 'Pug-French Bulldog Mix', 4),
#  ('female', 'Border Collie-Cocker Spaniel Mix', 4),
#  ('female', 'Labrador Retriever-Siberian Husky Mix', 4),
#  ('male', 'Dachshund-Beagle Mix', 4),
#  ('male', 'Irish Red and White Setter', 4),
#  ('female', 'Beagle-Jack Russell Terrier Mix', 4),
#  ('female', 'Rottweiler-German Shepherd Dog Mix', 4),
#  ('male', 'Bichon Frise-Maltese Mix', 4),
#  ('male', 'Chihuahua- Mix', 4),
#  ('female', 'Petit Basset Griffon Vendeen', 4),
#  ('male', 'Golden Retriever-Great Pyrenees Mix', 4),
#  ('female', 'Border Collie-English Springer Spaniel Mix', 4),
#  ('female', 'Chinook', 4),
#  ('male', 'Australian Shepherd- Mix', 4),
#  ('female', 'German Shepherd Dog-American Pit Bull Terrier Mix', 4),
#  ('male', 'Catahoula Leopard Dog-Australian Cattle Dog Mix', 4),
#  ('male', 'Entlebucher Mountain Dog', 4),
#  ('female', 'American Water Spaniel', 4),
#  ('male', 'Irish Water Spaniel', 4),
#  ('female', 'Golden Retriever-Collie Mix', 4),
#  ('male', 'American Water Spaniel', 4),
#  ('female', 'Chow Chow-Australian Shepherd Mix', 4),
#  ('male', 'Poodle-Pekingese Mix', 4),
#  ('female', 'Australian Shepherd-German Shepherd Dog Mix', 4),
#  ('female', 'Labrador Retriever-Chinese Shar-Pei Mix', 4),
#  ('female', 'Boston Terrier-Chihuahua Mix', 4),
#  ('female', 'Siberian Husky-Border Collie Mix', 4),
#  ('female', 'Yorkshire Terrier-Shih Tzu Mix', 4),
#  ('male', 'American Pit Bull Terrier-Great Dane Mix', 4),
#  ('female', 'Labrador Retriever-Cocker Spaniel Mix', 4),
#  ('male', 'Black Russian Terrier', 4),
#  ('male', 'Puli', 4),
#  ('male', 'Catahoula Leopard Dog-Labrador Retriever Mix', 4),
#  ('male', 'Border Collie-Flat-Coated Retriever Mix', 4),
#  ('female', 'Berger Picard', 4),
#  ('female', 'Kerry Blue Terrier', 4),
#  ('female', 'Chihuahua-Rat Terrier Mix', 4),
#  ('male', 'Pyrenean Shepherd', 4),
#  ('male', 'Spanish Water Dog', 4),
#  ('male', 'Yorkshire Terrier- Mix', 4),
#  ('female', 'Boerboel', 4),
#  ('female', 'American Pit Bull Terrier- Mix', 4),
#  ('female', 'Entlebucher Mountain Dog', 4),
#  ('male', 'Pharaoh Hound', 4),
#  ('female', 'German Shepherd Dog-Belgian Malinois Mix', 4),
#  ('male', 'Dachshund-Miniature Pinscher Mix', 4),
#  ('female', 'Bernese Mountain Dog-Great Pyrenees Mix', 3),
#  ('female', 'Labrador Retriever-Doberman Pinscher Mix', 3),
#  ('female', 'Beagle-Australian Cattle Dog Mix', 3),
#  ('male', 'Yorkshire Terrier-Bichon Frise Mix', 3),
#  ('male', 'Basset Hound-Beagle Mix', 3),
#  ('male', 'Australian Shepherd-German Shepherd Dog Mix', 3),
#  ('female', 'Australian Cattle Dog- Mix', 3),
#  ('female', 'Clumber Spaniel', 3),
#  ('male', 'American Pit Bull Terrier-Pointer Mix', 3),
#  ('male', 'American Eskimo Dog-Pomeranian Mix', 3),
#  ('male', 'German Shepherd Dog-Doberman Pinscher Mix', 3),
#  ('female', 'Doberman Pinscher-German Shepherd Dog Mix', 3),
#  ('female', 'Parson Russell Terrier-Rat Terrier Mix', 3),
#  ('female', 'Australian Cattle Dog-American Pit Bull Terrier Mix', 3),
#  ('female', 'Bugg', 3),
#  ('female', 'Poodle-Labrador Retriever Mix', 3),
#  ('male', 'American Pit Bull Terrier-Rhodesian Ridgeback Mix', 3),
#  ('female', 'American Pit Bull Terrier-Australian Shepherd Mix', 3),
#  ('female', 'Finnish Spitz', 3),
#  ('male', 'French Bulldog-Boston Terrier Mix', 3),
#  ('female', '-Pomeranian Mix', 3),
#  ('female', 'Dachshund-Beagle Mix', 3),
#  ('male', 'Dachshund-Poodle Mix', 3),
#  ('male', 'Siberian Husky-American Pit Bull Terrier Mix', 3),
#  ('female', 'Doberman Pinscher-Labrador Retriever Mix', 3),
#  ('female', 'Staffordshire Bull Terrier- Mix', 3),
#  ('male', 'Airedale Terrier-Labrador Retriever Mix', 3),
#  ('female', '-Poodle Mix', 3),
#  ('male', '-Border Collie Mix', 3),
#  ('male', 'Australian Cattle Dog-Beagle Mix', 3),
#  ('male', 'Labrador Retriever-English Springer Spaniel Mix', 3),
#  ('male', 'Dachshund-Pug Mix', 3),
#  ('male', 'Kooikerhondje', 3),
#  ('male', 'Collie-German Shepherd Dog Mix', 3),
#  ('male', 'Australian Shepherd-Pembroke Welsh Corgi Mix', 3),
#  ('female', 'German Shepherd Dog-Border Collie Mix', 3),
#  ('male', 'Jack Russell Terrier-Beagle Mix', 3),
#  ('male', 'French Spaniel', 3),
#  ('male', 'Poodle-Chihuahua Mix', 3),
#  ('male', 'Shetland Sheepdog-Border Collie Mix', 3),
#  ('female', 'Norfolk Terrier', 3),
#  ('male', '-German Shepherd Dog Mix', 3),
#  ('male', 'Bernese Mountain Dog-Poodle Mix', 3),
#  ('female', 'Border Collie-Shetland Sheepdog Mix', 3),
#  ('female', 'American Pit Bull Terrier-Bulldog Mix', 3),
#  ('female', 'Havanese-Poodle Mix', 3),
#  ('male', 'Collie-Labrador Retriever Mix', 3),
#  ('female', 'Chihuahua- Mix', 3),
#  ('male', 'Bull Terrier-Labrador Retriever Mix', 3),
#  ('female', 'Jack Russell Terrier-Pug Mix', 3),
#  ('male', 'Border Collie-Newfoundland Mix', 3),
#  ('female', 'Australian Shepherd- Mix', 3),
#  ('male', 'Parson Russell Terrier-Poodle Mix', 3),
#  ('male', 'Stabyhoun', 3),
#  ('female', 'Saluki', 3),
#  ('male', 'Border Collie-Pembroke Welsh Corgi Mix', 3),
#  ('male', 'West Highland White Terrier-Bichon Frise Mix', 3),
#  ('female', 'Pekingese-Poodle Mix', 3),
#  ('male', 'Akita-German Shepherd Dog Mix', 3),
#  ('female', 'German Shepherd Dog-Chinese Shar-Pei Mix', 3),
#  ('male', 'Yorkshire Terrier-Silky Terrier Mix', 3),
#  ('male', 'Australian Shepherd-Siberian Husky Mix', 3),
#  ('female', 'Labrador Retriever-Basset Hound Mix', 3),
#  ('male', 'Chihuahua-Pekingese Mix', 3),
#  ('male', 'Labrador Retriever-American Staffordshire Terrier Mix', 3),
#  ('female', 'Lowchen', 3),
#  ('male', 'Lowchen', 3),
#  ('male', 'Russell Terrier-Chihuahua Mix', 3),
#  ('female', 'Dachshund-Miniature Pinscher Mix', 3),
#  ('male', 'Chihuahua-Pembroke Welsh Corgi Mix', 3),
#  ('female', 'Bulldog-Boxer Mix', 3),
#  ('male', 'American Staffordshire Terrier-Boxer Mix', 3),
#  ('female', 'Border Collie-Bluetick Coonhound Mix', 3),
#  ('female', 'Labrador Retriever-Pointer Mix', 3),
#  ('male', 'Polish Lowland Sheepdog', 3),
#  ('female', 'Cardigan Welsh Corgi-German Shepherd Dog Mix', 3),
#  ('male', 'Staffordshire Bull Terrier-Australian Cattle Dog Mix', 3),
#  ('female', 'German Shepherd Dog-Golden Retriever Mix', 3),
#  ('male', 'American Staffordshire Terrier-Bullmastiff Mix', 3),
#  ('male', 'Tibetan Mastiff', 3),
#  ('female', 'Golden Retriever- Mix', 3),
#  ('male', 'Staffordshire Bull Terrier-Australian Kelpie Mix', 3),
#  ('female', 'Beagle-German Shepherd Dog Mix', 3),
#  ('female', 'Japanese Chin', 3),
#  ('female', 'Portuguese Podengo', 3),
#  ('female', 'Border Collie-Brittany Mix', 3),
#  ('female', 'Icelandic Sheepdog', 3),
#  ('female', 'Maltese-Bichon Frise Mix', 3),
#  ('female', 'Poodle- Mix', 3),
#  ('male', 'Border Collie-Shetland Sheepdog Mix', 3),
#  ('female', 'Standard Poodle-Golden Retriever Mix', 3),
#  ('male', 'German Shepherd Dog-Rhodesian Ridgeback Mix', 3),
#  ('male', 'Miniature Bull Terrier', 3),
#  ('female', 'Border Collie-Collie Mix', 3),
#  ('female', 'Australian Shepherd-Catahoula Leopard Dog Mix', 3),
#  ('male', 'Bichon Frise-Lhasa Apso Mix', 3),
#  ('male', 'Beagle-Border Collie Mix', 3),
#  ('female', 'Perro de Presa Canario', 3),
#  ('male', 'Great Pyrenees-Golden Retriever Mix', 3),
#  ('male', 'Pug-Miniature Pinscher Mix', 3),
#  ('male', 'Shih Tzu-Pekingese Mix', 3),
#  ('female', 'Australian Shepherd-Collie Mix', 3),
#  ('female', 'Rottweiler-Labrador Retriever Mix', 3),
#  ('female', '-Australian Shepherd Mix', 3),
#  ('male', 'Labrador Retriever-Boxer Mix', 3),
#  ('female', 'American Pit Bull Terrier-Siberian Husky Mix', 3),
#  ('female', 'Bloodhound-Black and Tan Coonhound Mix', 3),
#  ('male', 'Labrador Retriever-St. Bernard Mix', 3),
#  ('male', 'Rhodesian Ridgeback-Labrador Retriever Mix', 3),
#  ('female', 'Poodle-Chihuahua Mix', 3),
#  ('female', 'Beagle-Pug Mix', 3),
#  ('female', 'Collie-Golden Retriever Mix', 3),
#  ('female', 'Pug-Beagle Mix', 3),
#  ('female', 'Yorkshire Terrier-Pomeranian Mix', 3),
#  ('male', 'Doberman Pinscher-Labrador Retriever Mix', 3),
#  ('female', 'Shetland Sheepdog-Border Collie Mix', 3),
#  ('male', 'American Pit Bull Terrier-Bullmastiff Mix', 3),
#  ('male', 'Staffordshire Bull Terrier-Labrador Retriever Mix', 3),
#  ('female', 'German Shepherd Dog-Australian Cattle Dog Mix', 3),
#  ('male', 'Border Terrier-Lakeland Terrier Mix', 3),
#  ('female', 'Chihuahua-Pembroke Welsh Corgi Mix', 3),
#  ('male', 'Black and Tan Coonhound', 3),
#  ('male', 'Eurasier', 3),
#  ('female', 'Collie-Labrador Retriever Mix', 3),
#  ('female', 'Basset Hound-Labrador Retriever Mix', 3),
#  ('female', 'Australian Shepherd-Golden Retriever Mix', 3),
#  ('female', 'American Hairless Terrier', 3),
#  ('male', 'Russian Toy', 3),
#  ('female', 'Danish-Swedish Farmdog', 3),
#  ('male', 'Jindo', 3),
#  ('female', 'Australian Shepherd-Great Pyrenees Mix', 3),
#  ('male', 'Brittany-German Shorthaired Pointer Mix', 3),
#  ('female', 'Pug-Chihuahua Mix', 3),
#  ('female', 'Siberian Husky-Boxer Mix', 3),
#  ('male', 'Labrador Retriever-Chinese Shar-Pei Mix', 3),
#  ('female', 'Greyhound-Labrador Retriever Mix', 3),
#  ('male', 'Australian Shepherd-Chow Chow Mix', 3),
#  ('male', 'Greyhound-Border Collie Mix', 3),
#  ('male', 'Pumi', 3),
#  ('female', 'Chow Chow-Golden Retriever Mix', 3),
#  ('male', 'Shih Tzu-Yorkshire Terrier Mix', 3),
#  ('male', 'Pomeranian-Yorkshire Terrier Mix', 3),
#  ('female', 'Labrador Retriever-Dachshund Mix', 3),
#  ('male', 'Chinese Shar-Pei- Mix', 3),
#  ('female', 'Komondor', 3),
#  ('male', '-American Pit Bull Terrier Mix', 3),
#  ('male', 'Golden Retriever-St. Bernard Mix', 3),
#  ('male', 'Greyhound-Labrador Retriever Mix', 3),
#  ('female', 'Chow Chow-Labrador Retriever Mix', 3),
#  ('female', 'Bolognese', 3),
#  ('female', 'Parson Russell Terrier-Chihuahua Mix', 2),
#  ('male', 'Bloodhound-Labrador Retriever Mix', 2),
#  ('male', 'Greyhound-Saluki Mix', 2),
#  ('female', 'Boston Terrier-Pug Mix', 2),
#  ('female', 'Dachshund-American Pit Bull Terrier Mix', 2),
#  ('female', 'Kuvasz', 2),
#  ('female', 'Neapolitan Mastiff', 2),
#  ('female', 'Pug-Miniature Pinscher Mix', 2),
#  ('female', 'Siberian Husky-Keeshond Mix', 2),
#  ('male', 'Australian Cattle Dog- Mix', 2),
#  ('male', 'Labrador Retriever-Dachshund Mix', 2),
#  ('female', 'American Staffordshire Terrier-Border Collie Mix', 2),
#  ('female', 'Mastiff-Labrador Retriever Mix', 2),
#  ('male', 'American Pit Bull Terrier-Plott Mix', 2),
#  ('male', 'Beagle-Pointer Mix', 2),
#  ('male', 'Caucasian Ovcharka', 2),
#  ('female', 'Australian Shepherd-Rottweiler Mix', 2),
#  ('female', 'Chihuahua-Shih Tzu Mix', 2),
#  ('male', 'Italian Greyhound-Miniature Pinscher Mix', 2),
#  ('male', 'Poodle-Australian Cattle Dog Mix', 2),
#  ('male', 'Scottish Deerhound', 2),
#  ('female', 'Rhodesian Ridgeback-Boxer Mix', 2),
#  ('male', 'Chinese Shar-Pei-German Shepherd Dog Mix', 2),
#  ('male', 'Greyhound-Staffordshire Bull Terrier Mix', 2),
#  ('female', '-Maltese Mix', 2),
#  ('female', 'German Shorthaired Pointer-Catahoula Leopard Dog Mix', 2),
#  ('male', 'Papillon-Japanese Chin Mix', 2),
#  ('male', 'Rat Terrier-Basenji Mix', 2),
#  ('female', 'Shih Tzu-Brussels Griffon Mix', 2),
#  ('male', 'Dachshund-Parson Russell Terrier Mix', 2),
#  ('male', 'Yorkshire Terrier-Cairn Terrier Mix', 2),
#  ('female', 'American Pit Bull Terrier-Australian Cattle Dog Mix', 2),
#  ('female', 'Polish Lowland Sheepdog', 2),
#  ('male', 'Border Collie-Great Dane Mix', 2),
#  ('male', 'Border Collie-Great Pyrenees Mix', 2),
#  ('female', 'Bernese Mountain Dog-Labrador Retriever Mix', 2),
#  ('male', 'Standard Poodle-Soft Coated Wheaten Terrier Mix', 2),
#  ('female', 'Dachshund-Basset Hound Mix', 2),
#  ('male', 'Bernese Mountain Dog-Border Collie Mix', 2),
#  ('male', 'Boxer-German Shepherd Dog Mix', 2),
#  ('male', 'Papillon-Pomeranian Mix', 2),
#  ('female', 'Jack Russell Terrier-Cavalier King Charles Spaniel Mix', 2),
#  ('female', 'Chihuahua-Whippet Mix', 2),
#  ('female', 'Russell Terrier-Rat Terrier Mix', 2),
#  ('male', 'Collie- Mix', 2),
#  ('male', 'Italian Greyhound-Russell Terrier Mix', 2),
#  ('female', 'Australian Kelpie-Labrador Retriever Mix', 2),
#  ('male', 'Brussels Griffon-Pug Mix', 2),
#  ('female', 'Pug-Russell Terrier Mix', 2),
#  ('female', 'Siberian Husky-Rottweiler Mix', 2),
#  ('male', 'Papillon-Poodle Mix', 2),
#  ('female', 'Poodle-Lhasa Apso Mix', 2),
#  ('male', 'Beagle-Rat Terrier Mix', 2),
#  ('male', 'Komondor', 2),
#  ('female', 'American Pit Bull Terrier-Beagle Mix', 2),
#  ('male', 'Border Collie-Irish Setter Mix', 2),
#  ('male', 'Sealyham Terrier', 2),
#  ('female', 'Golden Retriever-Standard Poodle Mix', 2),
#  ('male', 'Bernese Mountain Dog-Golden Retriever Mix', 2),
#  ('female', 'Cocker Spaniel-Bichon Frise Mix', 2),
#  ('male', 'Cavalier King Charles Spaniel-Cocker Spaniel Mix', 2),
#  ('female', 'American Pit Bull Terrier-Boston Terrier Mix', 2),
#  ('male', 'Basset Hound-Labrador Retriever Mix', 2),
#  ('male', 'Jack Russell Terrier-American Pit Bull Terrier Mix', 2),
#  ('female', 'Australian Kelpie-Staffordshire Bull Terrier Mix', 2),
#  ('female', 'Staffordshire Bull Terrier-Australian Cattle Dog Mix', 2),
#  ('male', 'Bolognese', 2),
#  ('male', 'French Bulldog-Pug Mix', 2),
#  ('female', '-Russell Terrier Mix', 2),
#  ('male', '-Boxer Mix', 2),
#  ('male', 'Chihuahua-Maltese Mix', 2),
#  ('male', 'Great Dane-American Staffordshire Terrier Mix', 2),
#  ('female', 'Border Collie-Poodle Mix', 2),
#  ('female', 'Cocker Spaniel-Cavalier King Charles Spaniel Mix', 2),
#  ('female', 'Miniature Bull Terrier', 2),
#  ('male', 'Boston Terrier-Bulldog Mix', 2),
#  ('male', 'Dachshund-Rat Terrier Mix', 2),
#  ('female', 'Doberman Pinscher-Rottweiler Mix', 2),
#  ('female', 'Labrador Retriever-Great Pyrenees Mix', 2),
#  ('female', 'Rhodesian Ridgeback-Labrador Retriever Mix', 2),
#  ('female', 'Staffordshire Bull Terrier-Border Collie Mix', 2),
#  ('female', '-Shih Tzu Mix', 2),
#  ('male', 'Labrador Retriever-Flat-Coated Retriever Mix', 2),
#  ('male', 'Parson Russell Terrier- Mix', 2),
#  ('female', 'Bull Terrier-Staffordshire Bull Terrier Mix', 2),
#  ('male', 'Beagle-Treeing Walker Coonhound Mix', 2),
#  ('male', 'Cavalier King Charles Spaniel-Coton de Tulear Mix', 2),
#  ('male', 'Miniature Schnauzer-Wire Fox Terrier Mix', 2),
#  ('female', 'American Pit Bull Terrier-Bull Terrier Mix', 2),
#  ('female', 'Havanese-Pekingese Mix', 2),
#  ('female', 'Lhasa Apso-Maltese Mix', 2),
#  ('male', 'Mastiff-American Pit Bull Terrier Mix', 2),
#  ('female', 'Australian Labradoodle-Poodle Mix', 2),
#  ('female', 'Labrador Retriever-Greyhound Mix', 2),
#  ('male', 'Akita-Afghan Hound Mix', 2),
#  ('male', 'Border Collie- Mix', 2),
#  ('female', 'Dachshund-Doberman Pinscher Mix', 2),
#  ('male', 'Rat Terrier-Dachshund Mix', 2),
#  ('female', 'Bull Terrier-Whippet Mix', 2),
#  ('male', 'Miniature Schnauzer-Yorkshire Terrier Mix', 2),
#  ('male', 'Yorkshire Terrier-Pekingese Mix', 2),
#  ('female', 'Border Collie-Beagle Mix', 2),
#  ('male', 'American Foxhound-Labrador Retriever Mix', 2),
#  ('male', 'Jack Russell Terrier-Chihuahua Mix', 2),
#  ('male', 'Shetland Sheepdog-Collie Mix', 2),
#  ('female', 'Alaskan Malamute-Labrador Retriever Mix', 2),
#  ('male', 'German Longhaired Pointer', 2),
#  ('male', 'Russell Terrier- Mix', 2),
#  ('female', 'Beagle-Cavalier King Charles Spaniel Mix', 2),
#  ('female', 'American Staffordshire Terrier-German Shepherd Dog Mix', 2),
#  ('female', 'Border Collie-Bearded Collie Mix', 2),
#  ('female', 'Labrador Retriever-Mastiff Mix', 2),
#  ('female', 'Staffordshire Bull Terrier-Bullmastiff Mix', 2),
#  ('male', 'Border Collie-American Eskimo Dog Mix', 2),
#  ('male', 'Chow Chow-Golden Retriever Mix', 2),
#  ('male', 'Havanese-Maltese Mix', 2),
#  ('male', 'Golden Retriever-Australian Shepherd Mix', 2),
#  ('male', 'Pug- Mix', 2),
#  ('male', 'Siberian Husky-Border Collie Mix', 2),
#  ('female', 'Lhasa Apso-Shih Tzu Mix', 2),
#  ('male', 'Mastiff-Great Dane Mix', 2),
#  ('male', 'Poodle-Dachshund Mix', 2),
#  ('female', 'Alaskan Malamute-Siberian Husky Mix', 2),
#  ('female', 'Giant Schnauzer-Standard Poodle Mix', 2),
#  ('female', 'Silky Terrier-Poodle Mix', 2),
#  ('male', 'Australian Cattle Dog-Labrador Retriever Mix', 2),
#  ('male', 'Parson Russell Terrier-Russell Terrier Mix', 2),
#  ('female', 'Border Collie-Staffordshire Bull Terrier Mix', 2),
#  ('female', 'American Staffordshire Terrier-Golden Retriever Mix', 2),
#  ('female', 'Miniature Pinscher-Rat Terrier Mix', 2),
#  ('female', 'Poodle-Russell Terrier Mix', 2),
#  ('male', 'Dalmatian-American Pit Bull Terrier Mix', 2),
#  ('male', 'Pug-American Pit Bull Terrier Mix', 2),
#  ('female', 'Chinese Crested-Poodle Mix', 2),
#  ('female', 'Saluki-Greyhound Mix', 2),
#  ('female', 'Staffordshire Bull Terrier-Whippet Mix', 2),
#  ('male', 'Bulldog-American Pit Bull Terrier Mix', 2),
#  ('male', 'Havanese-Shih Tzu Mix', 2),
#  ('male', 'Russell Terrier-Beagle Mix', 2),
#  ('male', 'Thai Ridgeback', 2),
#  ('female', 'Australian Cattle Dog-Bluetick Coonhound Mix', 2),
#  ('male', 'English Setter-Labrador Retriever Mix', 2),
#  ('female', 'Beagle-Cocker Spaniel Mix', 2),
#  ('male', 'Dalmatian-Labrador Retriever Mix', 2),
#  ('male', 'Pug-Boston Terrier Mix', 2),
#  ('male', 'Siberian Husky-Greyhound Mix', 2),
#  ('male', 'Mastiff-Labrador Retriever Mix', 2),
#  ('male', 'Australian Shepherd-Standard Poodle Mix', 2),
#  ('male', 'Pointer-Labrador Retriever Mix', 2),
#  ('female', 'Rat Terrier-Beagle Mix', 2),
#  ('female', 'Skye Terrier', 2),
#  ('male', 'Australian Cattle Dog-Siberian Husky Mix', 2),
#  ('male', 'Boxer-Rhodesian Ridgeback Mix', 2),
#  ('female', 'Beagle-Collie Mix', 2),
#  ('female', 'German Shepherd Dog-Collie Mix', 2),
#  ('female', 'Miniature Pinscher-Shih Tzu Mix', 2),
#  ('female', 'Shih Tzu-Pomeranian Mix', 2),
#  ('male', 'American Staffordshire Terrier-Bull Terrier Mix', 2),
#  ('male', 'Dandie Dinmont Terrier', 2),
#  ('male', 'Pug-Brussels Griffon Mix', 2),
#  ('male', 'American Pit Bull Terrier- Mix', 2),
#  ('male', 'Border Collie-Rottweiler Mix', 2),
#  ('male', 'Curly-Coated Retriever', 2),
#  ('male', 'Poodle-German Shepherd Dog Mix', 2),
#  ('male', 'West Highland White Terrier-Poodle Mix', 2),
#  ('female', 'Australian Cattle Dog-Boxer Mix', 2),
#  ('female', 'Border Collie-Whippet Mix', 2),
#  ('female', 'Miniature Schnauzer- Mix', 2),
#  ('female', 'Shih Tzu-Pug Mix', 2),
#  ('male', 'Border Collie-Saluki Mix', 2),
#  ('female', 'Pembroke Welsh Corgi-Australian Cattle Dog Mix', 2),
#  ('male', 'Border Collie-Bearded Collie Mix', 2),
#  ('male', 'Bulldog-Beagle Mix', 2),
#  ('female', 'Boxer-Dutch Shepherd Mix', 2),
#  ('female', 'Australian Cattle Dog-Bull Terrier Mix', 2),
#  ('female', 'Dachshund-Poodle Mix', 2),
#  ('male', 'Chihuahua-Poodle Mix', 2),
#  ('male', 'American Staffordshire Terrier-Chinese Shar-Pei Mix', 2),
#  ('male', 'Danish-Swedish Farmdog', 2),
#  ('female', 'French Spaniel', 2),
#  ('male', 'Cardigan Welsh Corgi-American Pit Bull Terrier Mix', 2),
#  ('male', 'Whippet-Border Collie Mix', 2),
#  ('male', 'Cirneco dell"Etna', 2),
#  ('male', 'Ibizan Hound', 2),
#  ('female', 'Dachshund-Rat Terrier Mix', 2),
#  ('male', 'Staffordshire Bull Terrier-Beagle Mix', 2),
#  ('male', 'American Staffordshire Terrier-Dogo Argentino Mix', 2),
#  ('male', 'Labrador Retriever-Basset Hound Mix', 2),
#  ('female', 'German Longhaired Pointer', 2),
#  ('male', 'German Shepherd Dog-Redbone Coonhound Mix', 2),
#  ('male', 'Poodle-Havanese Mix', 2),
#  ('male', 'Bulldog-Boxer Mix', 2),
#  ('female', 'Belgian Malinois-Labrador Retriever Mix', 2),
#  ('female', 'Dachshund-Russell Terrier Mix', 2),
#  ('male', 'English Springer Spaniel-Border Collie Mix', 2),
#  ('female', 'Border Terrier- Mix', 2),
#  ('female', 'German Shepherd Dog-Keeshond Mix', 2),
#  ('female', 'German Pinscher', 2),
#  ('female', 'Irish Red and White Setter', 2),
#  ('male', 'Poodle-Japanese Chin Mix', 2),
#  ('female', 'Chihuahua-Italian Greyhound Mix', 2),
#  ('female', 'Rottweiler-Collie Mix', 2),
#  ('male', 'Bulldog-Bullmastiff Mix', 2),
#  ('female', 'Belgian Malinois-Siberian Husky Mix', 2),
#  ('male', 'English Springer Spaniel-Cocker Spaniel Mix', 2),
#  ('female', 'Portuguese Podengo Pequeno-Jack Russell Terrier Mix', 2),
#  ('male', 'Chesapeake Bay Retriever-Siberian Husky Mix', 2),
#  ('male', 'Golden Retriever-Collie Mix', 2),
#  ('male', 'Siberian Husky-Shiba Inu Mix', 2),
#  ...]

# %% [markdown]
# Some database servers, including MySQL, allow you to use numbers in place of field names in the GROUP BY or ORDER BY fields to reduce the overall length of the queries.  I tend to avoid this abbreviated method of writing queries because I find it challenging to troubleshoot when you are writing complicated queries with many fields, but it does allow you to write queries faster.  To use this method, assign each field in your SELECT statement a number acording to the order the field appears in the SELECT statement.  In the following statement:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# ```
#
# test_name would be #1, Month would be #2, and Num_Completed_Tests would be #3.  You could then rewrite the query above to read:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY 1, 2
# ORDER BY 1 ASC, 2 ASC;
# ```
#
# **Question 2: Revise the query your wrote in Question 1 so that it uses only numbers in the GROUP BY and ORDER BY fields.**

# %%
# %%sql
# SELECT gender,breed_group,COUNT(DISTINCT dog_guid) AS num_dogs
# FROM dogs
# GROUP BY 1,2
# ORDER BY 3 DESC;
# Out:
# 18 rows affected.
# [('male', None, 8466),
#  ('female', None, 8367),
#  ('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075),
#  ('male', 'Terrier', 919),
#  ('female', 'Non-Sporting', 919),
#  ('female', 'Working', 895),
#  ('female', 'Terrier', 794),
#  ('male', 'Hound', 725),
#  ('female', 'Hound', 614),
#  ('male', '', 147),
#  ('female', '', 127)]

# %% [markdown]
# ## The HAVING clause
#
# Just like you can query subsets of rows using the WHERE clause, you can query subsets of aggregated groups using the HAVING clause.  However, wheras the expression that follows a WHERE clause has to be applicable to each row of data in a column, the expression that follows a HAVING clause has to be applicable or computable using a group of data.
#
# If you wanted to examine the number of tests completed only during the winter holiday months of November and December, you would need to use a WHERE clause, because the month a test was completed in is recorded in each row.  Your query might look like this:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# ORDER BY 3 DESC;
# ```
# If you then wanted to output only the test-month pairs that had at least 20 records in them, you would add a HAVING clause, because the stipulation of at least 20 records only makes sense and is only computable at the aggregated group level:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# HAVING COUNT(created_at)>=20
# ORDER BY 3 DESC;
# ```
#
# **Question 3: Revise the query your wrote in Question 2 so that it (1) excludes the NULL and empty string entries in the breed_group field, and (2) excludes any groups that don't have at least 1,000 distinct Dog_Guids in them.  Your result should contain 8 rows.  (HINT: sometimes empty strings are registered as non-NULL values.  You might want to include the following line somewhere in your query to exclude these values as well):**
#
# ```mySQL
# breed_group!=""
# ```

# %%
# %%sql
# SELECT gender,breed_group,COUNT(DISTINCT dog_guid) AS num_dogs
# FROM dogs
# WHERE breed_group IS NOT NULL AND breed_group!=""
# GROUP BY 1,2
# HAVING num_dogs>=1000
# ORDER BY 3 DESC;
# Out:
# 8 rows affected.
# [('male', 'Sporting', 2584),
#  ('female', 'Sporting', 2262),
#  ('male', 'Herding', 1736),
#  ('female', 'Herding', 1704),
#  ('male', 'Toy', 1473),
#  ('female', 'Toy', 1145),
#  ('male', 'Non-Sporting', 1098),
#  ('male', 'Working', 1075)]

# %% [markdown]
# We will review several issues that can be tricky about using GROUP BY in your queries in the next lesson, but those issues will make more sense once you are sure you are comfortable with the basic functionality of the GROUP BY and HAVING clauses.
#
#
#
# ## Practice incorporating GROUP BY and HAVING into your own queries.
#
# **Question 4: Write a query that outputs the average number of tests completed and average mean inter-test-interval for every breed type, sorted by the average number of completed tests in descending order (popular hybrid should be the first row in your output).**

# %%
# %%sql
# SELECT breed_type,AVG(total_tests_completed) AS avg_test_completed,AVG(mean_iti_days) AS avg_mean_iti_days
# FROM dogs
# GROUP BY breed_type
# ORDER BY avg_test_completed DESC;
# Out:
# 4 rows affected.
# [('Popular Hybrid', 10.257530120481928, 1.9682781756219017),
#  ('Cross Breed', 9.945900537634408, 1.994688302855342),
#  ('Pure Breed', 9.871602824737856, 2.2176045095807226),
#  ("Mixed Breed/ Other/ I Don't Know", 9.54250850170034, 2.0993549515344747)]

# %% [markdown]
# **Question 5: Write a query that outputs the average amount of time it took customers to complete each type of test where any individual reaction times over 6000 hours are excluded and only average reaction times that are greater than 0 seconds are included (your output should end up with 67 rows).**

# %%
# %%sql
# SELECT test_name,AVG(TIMESTAMPDIFF(SECOND,start_time,end_time)) AS avg_time
# FROM exam_answers
# WHERE TIMESTAMPDIFF(HOUR,start_time,end_time)<=6000
# GROUP BY test_name
# HAVING avg_time>0;
# Out:
# 67 rows affected.
# [('1 vs 1 Game', Decimal('12.2278')),
#  ('3 vs 1 Game', Decimal('11.8237')),
#  ('5 vs 1 Game', Decimal('11.7260')),
#  ('Activity', Decimal('72107.3552')),
#  ('Arm Pointing', Decimal('2204.4255')),
#  ('Attachment', Decimal('39820.6776')),
#  ('Confinement', Decimal('33160.8799')),
#  ('Cover Your Eyes', Decimal('3057.7534')),
#  ('Delayed Cup Game', Decimal('5146.6577')),
#  ('Diet', Decimal('118082.3240')),
#  ('Different Perspective', Decimal('209.2164')),
#  ('Emotions', Decimal('16814.9158')),
#  ('Environment', Decimal('1803.5387')),
#  ('Excitability', Decimal('39607.1763')),
#  ('Expression Game', Decimal('10.3948')),
#  ('Eye Contact Game', Decimal('4177.7206')),
#  ('Eye Contact Warm-up', Decimal('4431.6406')),
#  ('Foot Pointing', Decimal('2075.6727')),
#  ('Gender', Decimal('22102.0976')),
#  ('Impossible Task Game', Decimal('737.3073')),
#  ('Impossible Task Warm-up', Decimal('13706.5646')),
#  ('Inferential Reasoning Game', Decimal('1408.4918')),
#  ('Inferential Reasoning Warm-up', Decimal('4993.8225')),
#  ('Memory versus Pointing', Decimal('803.2993')),
#  ('Memory versus Smell', Decimal('4289.5062')),
#  ('Navigation Game', Decimal('482.5239')),
#  ('Navigation Learning', Decimal('832.0526')),
#  ('Navigation Warm-up', Decimal('22267.6312')),
#  ('Numerosity Warm-Up', Decimal('16555.1668')),
#  ('Obedience', Decimal('12484.6163')),
#  ('One Cup Warm-up', Decimal('5127.8852')),
#  ('Owner', Decimal('18845.3157')),
#  ('Partnership', Decimal('12522.0659')),
#  ('Perception', Decimal('13765.2964')),
#  ('Physical', Decimal('20531.2929')),
#  ('Physical Reasoning Game', Decimal('313.1619')),
#  ('Physical Reasoning Warm-up', Decimal('1783.8529')),
#  ('Purina', Decimal('8892.4649')),
#  ('Purina-Only', Decimal('12149.4894')),
#  ('Puzzles', Decimal('13585.2381')),
#  ('Recall', Decimal('13776.8336')),
#  ('Self Control Game', Decimal('9.5476')),
#  ('Set 1', Decimal('11182.7955')),
#  ('Set 2', Decimal('494.1049')),
#  ('Set 3', Decimal('25270.5216')),
#  ('Shaker Game', Decimal('7.5290')),
#  ('Shaker Warm-Up', Decimal('250.2791')),
#  ('Shared Perspective', Decimal('19.9822')),
#  ('Shy/Boldness', Decimal('41841.0608')),
#  ('Slide', Decimal('1939.4002')),
#  ('Smell Game', Decimal('4269.2443')),
#  ('Sociability', Decimal('76277.5590')),
#  ('Social', Decimal('9936.3177')),
#  ('Social-Quiz', Decimal('295506.3557')),
#  ('Stair Game', Decimal('1113.1217')),
#  ('Surprise And Delight', Decimal('39422.4842')),
#  ('Switch', Decimal('202.8889')),
#  ('Toys', Decimal('7979.4031')),
#  ('Training', Decimal('9409.3918')),
#  ('Treat Warm-up', Decimal('8003.6668')),
#  ('Turn Your Back', Decimal('2846.7845')),
#  ('Two Cup Warm-up', Decimal('456.4392')),
#  ('Warm-Up', Decimal('7520.0704')),
#  ('Watching', Decimal('41444.4840')),
#  ('Watching - Part 2', Decimal('7961.9341')),
#  ('Yawn Game', Decimal('13847.9040')),
#  ('Yawn Warm-up', Decimal('55050.2272'))]

# %% [markdown]
# **Question 6: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code (postal code) in the United States, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state should be AE and there should be 5043 rows in total in your output).**

# %%
# %%sql
# SELECT COUNT(DISTINCT user_guid) AS num_user_guid,state,zip
# FROM users
# WHERE country="US"
# GROUP BY state,zip
# ORDER BY state,num_user_guid DESC;
# Out:
# 5043 rows affected.
# [(2, 'AE', '9128'),
#  (1, 'AE', '9053'),
#  (1, 'AE', '9107'),
#  (1, 'AE', '9469'),
#  (1, 'AE', '9845'),
#  (3, 'AK', '99709'),
#  (3, 'AK', '99507'),
#  (2, 'AK', '99501'),
#  (2, 'AK', '99577'),
#  (1, 'AK', '99611'),
#  (1, 'AK', '99645'),
#  (1, 'AK', '99676'),
#  (1, 'AK', '99705'),
#  (1, 'AK', '99712'),
#  (1, 'AK', '99752'),
#  (1, 'AK', '99775'),
#  (1, 'AK', '99824'),
#  (1, 'AK', '99928'),
#  (1, 'AK', '99502'),
#  (1, 'AK', '99509'),
#  (1, 'AK', '99516'),
#  (1, 'AK', '99518'),
#  (1, 'AK', '99567'),
#  (1, 'AK', '99587'),
#  (4, 'AL', '35209'),
#  (2, 'AL', '36116'),
#  (2, 'AL', '36532'),
#  (2, 'AL', '36609'),
#  (2, 'AL', '35801'),
#  (1, 'AL', '36104'),
#  (1, 'AL', '36106'),
#  (1, 'AL', '36203'),
#  (1, 'AL', '36303'),
#  (1, 'AL', '36375'),
#  (1, 'AL', '36527'),
#  (1, 'AL', '36561'),
#  (1, 'AL', '36602'),
#  (1, 'AL', '36604'),
#  (1, 'AL', '35004'),
#  (1, 'AL', '35007'),
#  (1, 'AL', '36695'),
#  (1, 'AL', '35094'),
#  (1, 'AL', '35121'),
#  (1, 'AL', '36801'),
#  (1, 'AL', '35179'),
#  (1, 'AL', '36832'),
#  (1, 'AL', '35205'),
#  (1, 'AL', '35216'),
#  (1, 'AL', '35242'),
#  (1, 'AL', '35405'),
#  (1, 'AL', '35476'),
#  (1, 'AL', '35646'),
#  (1, 'AL', '35662'),
#  (1, 'AL', '35674'),
#  (1, 'AL', '35758'),
#  (1, 'AL', '35760'),
#  (1, 'AL', '35763'),
#  (1, 'AL', '35803'),
#  (1, 'AL', '35906'),
#  (1, 'AL', '35976'),
#  (1, 'AL', '36037'),
#  (1, 'AP', '96205'),
#  (1, 'AP', '96310'),
#  (1, 'AP', '96367'),
#  (1, 'AP', '96377'),
#  (3, 'AR', '72401'),
#  (3, 'AR', '72207'),
#  (2, 'AR', '72223'),
#  (2, 'AR', '72632'),
#  (2, 'AR', '72712'),
#  (1, 'AR', '72554'),
#  (1, 'AR', '72631'),
#  (1, 'AR', '72701'),
#  (1, 'AR', '72703'),
#  (1, 'AR', '72704'),
#  (1, 'AR', '72714'),
#  (1, 'AR', '72756'),
#  (1, 'AR', '72762'),
#  (1, 'AR', '72802'),
#  (1, 'AR', '72901'),
#  (1, 'AR', '72908'),
#  (1, 'AR', '72956'),
#  (1, 'AR', '71909'),
#  (1, 'AR', '71913'),
#  (1, 'AR', '72015'),
#  (1, 'AR', '72034'),
#  (1, 'AR', '72042'),
#  (1, 'AR', '72058'),
#  (1, 'AR', '72113'),
#  (1, 'AR', '72135'),
#  (1, 'AR', '72201'),
#  (1, 'AR', '72202'),
#  (1, 'AR', '72206'),
#  (1, 'AR', '72212'),
#  (14, 'AZ', '86303'),
#  (6, 'AZ', '85718'),
#  (5, 'AZ', '85260'),
#  (5, 'AZ', '85711'),
#  (5, 'AZ', '85749'),
#  (5, 'AZ', '85253'),
#  (5, 'AZ', '85254'),
#  (4, 'AZ', 'N/A'),
#  (4, 'AZ', '85266'),
#  (4, 'AZ', '85716'),
#  (4, 'AZ', '85719'),
#  (4, 'AZ', '85750'),
#  (3, 'AZ', '85257'),
#  (3, 'AZ', '85044'),
#  (3, 'AZ', '85048'),
#  (3, 'AZ', '85282'),
#  (3, 'AZ', '85283'),
#  (3, 'AZ', '85296'),
#  (3, 'AZ', '85737'),
#  (3, 'AZ', '86305'),
#  (3, 'AZ', '85392'),
#  (3, 'AZ', '85233'),
#  (3, 'AZ', '85021'),
#  (3, 'AZ', '85022'),
#  (3, 'AZ', '85250'),
#  (3, 'AZ', '85032'),
#  (3, 'AZ', '85255'),
#  (3, 'AZ', '85042'),
#  (2, 'AZ', '85259'),
#  (2, 'AZ', '85045'),
#  (2, 'AZ', '85704'),
#  (2, 'AZ', '85086'),
#  (2, 'AZ', '85712'),
#  (2, 'AZ', '85281'),
#  (2, 'AZ', '85715'),
#  (2, 'AZ', '85304'),
#  (2, 'AZ', '85739'),
#  (2, 'AZ', '85143'),
#  (2, 'AZ', '85202'),
#  (2, 'AZ', '85745'),
#  (2, 'AZ', '85203'),
#  (2, 'AZ', '85748'),
#  (2, 'AZ', '85206'),
#  (2, 'AZ', '85374'),
#  (2, 'AZ', '85024'),
#  (2, 'AZ', '85615'),
#  (2, 'AZ', '85251'),
#  (2, 'AZ', '85028'),
#  (2, 'AZ', '86351'),
#  (1, 'AZ', '86426'),
#  (1, 'AZ', '85646'),
#  (1, 'AZ', '86504'),
#  (1, 'AZ', '85650'),
#  (1, 'AZ', '85658'),
#  (1, 'AZ', '85050'),
#  (1, 'AZ', '85262'),
#  (1, 'AZ', '85069'),
#  (1, 'AZ', '85710'),
#  (1, 'AZ', '85083'),
#  (1, 'AZ', '85268'),
#  (1, 'AZ', '85118'),
#  (1, 'AZ', '85119'),
#  (1, 'AZ', '85120'),
#  (1, 'AZ', '85284'),
#  (1, 'AZ', '85122'),
#  (1, 'AZ', '85286'),
#  (1, 'AZ', '85128'),
#  (1, 'AZ', '85730'),
#  (1, 'AZ', '85303'),
#  (1, 'AZ', '85138'),
#  (1, 'AZ', '85140'),
#  (1, 'AZ', '85308'),
#  (1, 'AZ', '85743'),
#  (1, 'AZ', '85327'),
#  (1, 'AZ', '85335'),
#  (1, 'AZ', '85338'),
#  (1, 'AZ', '85205'),
#  (1, 'AZ', '85006'),
#  (1, 'AZ', '85340'),
#  (1, 'AZ', '85008'),
#  (1, 'AZ', '85353'),
#  (1, 'AZ', '85207'),
#  (1, 'AZ', '85012'),
#  (1, 'AZ', '85755'),
#  (1, 'AZ', '85365'),
#  (1, 'AZ', '85209'),
#  (1, 'AZ', '85013'),
#  (1, 'AZ', '86002'),
#  (1, 'AZ', '85210'),
#  (1, 'AZ', '85015'),
#  (1, 'AZ', '86301'),
#  (1, 'AZ', '85382'),
#  (1, 'AZ', '85212'),
#  (1, 'AZ', '85016'),
#  (1, 'AZ', '85385'),
#  (1, 'AZ', '85226'),
#  (1, 'AZ', '85020'),
#  (1, 'AZ', '86312'),
#  (1, 'AZ', '86314'),
#  (1, 'AZ', '85248'),
#  (1, 'AZ', '86323'),
#  (1, 'AZ', '85614'),
#  (1, 'AZ', '85249'),
#  (1, 'AZ', '86326'),
#  (1, 'AZ', '85027'),
#  (1, 'AZ', '86327'),
#  (1, 'AZ', '85622'),
#  (1, 'AZ', '86336'),
#  (1, 'AZ', '85635'),
#  (1, 'AZ', '85029'),
#  (1, 'AZ', '85636'),
#  (1, 'AZ', '86403'),
#  (1, 'AZ', '85641'),
#  (16, 'CA', '92107'),
#  (13, 'CA', '90046'),
#  (12, 'CA', '94107'),
#  (12, 'CA', '92130'),
#  (10, 'CA', '94110'),
#  (10, 'CA', '92024'),
#  (9, 'CA', '94114'),
#  (9, 'CA', '94941'),
#  (9, 'CA', '94025'),
#  (9, 'CA', '94611'),
#  (8, 'CA', '90068'),
#  (8, 'CA', '90069'),
#  (8, 'CA', '94131'),
#  (8, 'CA', '92064'),
#  (8, 'CA', '90049'),
#  (7, 'CA', '90803'),
#  (7, 'CA', '93003'),
#  (7, 'CA', '94117'),
#  (7, 'CA', '94121'),
#  (7, 'CA', '90266'),
#  (7, 'CA', '94602'),
#  (7, 'CA', '90278'),
#  (7, 'CA', '90291'),
#  (7, 'CA', '90292'),
#  (6, 'CA', '92103'),
#  (6, 'CA', '94901'),
#  (6, 'CA', '94903'),
#  (6, 'CA', '92672'),
#  (6, 'CA', '94123'),
#  (6, 'CA', '90274'),
#  (6, 'CA', '94952'),
#  (6, 'CA', '90277'),
#  (6, 'CA', '90036'),
#  (6, 'CA', '94549'),
#  (6, 'CA', '90039'),
#  (6, 'CA', '94061'),
#  (6, 'CA', '95762'),
#  (6, 'CA', '92071'),
#  (6, 'CA', '95008'),
#  (6, 'CA', '95014'),
#  (6, 'CA', '91301'),
#  (5, 'CA', '94706'),
#  (5, 'CA', '94510'),
#  (5, 'CA', '94109'),
#  (5, 'CA', '93940'),
#  (5, 'CA', '92106'),
#  (5, 'CA', '90210'),
#  (5, 'CA', '94904'),
#  (5, 'CA', '93012'),
#  (5, 'CA', '94118'),
#  (5, 'CA', '90232'),
#  (5, 'CA', '93023'),
#  (5, 'CA', '90025'),
#  (5, 'CA', '94597'),
#  (5, 'CA', '92122'),
#  (5, 'CA', '94040'),
#  (5, 'CA', '93105'),
#  (5, 'CA', '95476'),
#  (5, 'CA', '94550'),
#  (5, 'CA', '91406'),
#  (5, 'CA', '95003'),
#  (5, 'CA', '92211'),
#  (5, 'CA', '95818'),
#  (5, 'CA', '90405'),
#  (5, 'CA', '92101'),
#  (5, 'CA', '92009'),
#  (4, 'CA', '90720'),
#  (4, 'CA', '95608'),
#  (4, 'CA', '91307'),
#  (4, 'CA', '95616'),
#  (4, 'CA', '95401'),
#  (4, 'CA', '90004'),
#  (4, 'CA', '92649'),
#  (4, 'CA', '92886'),
#  (4, 'CA', '95403'),
#  (4, 'CA', '91320'),
#  (4, 'CA', '90211'),
#  (4, 'CA', '94523'),
#  (4, 'CA', '95404'),
#  (4, 'CA', '92656'),
#  (4, 'CA', '92109'),
#  (4, 'CA', '90212'),
#  (4, 'CA', '94583'),
#  (4, 'CA', '92026'),
#  (4, 'CA', '95407'),
#  (4, 'CA', '92660'),
#  (4, 'CA', '92116'),
#  (4, 'CA', '92117'),
#  (4, 'CA', '90265'),
#  (4, 'CA', '94127'),
#  (4, 'CA', '92677'),
#  (4, 'CA', '90026'),
#  (4, 'CA', '90027'),
#  (4, 'CA', '91367'),
#  (4, 'CA', '91030'),
#  (4, 'CA', '93103'),
#  (4, 'CA', '92126'),
#  (4, 'CA', '90034'),
#  (4, 'CA', '93561'),
#  (4, 'CA', '95472'),
#  (4, 'CA', '92128'),
#  (4, 'CA', '95125'),
#  (4, 'CA', '94965'),
#  (4, 'CA', '92067'),
#  (4, 'CA', '94306'),
#  (4, 'CA', '94062'),
#  (4, 'CA', '92612'),
#  (4, 'CA', '94403'),
#  (4, 'CA', '91941'),
#  (4, 'CA', '90404'),
#  (4, 'CA', '92078'),
#  (4, 'CA', '94558'),
#  (4, 'CA', '91942'),
#  (4, 'CA', '94501'),
#  (4, 'CA', '94703'),
#  (4, 'CA', '94506'),
#  (3, 'CA', '92646'),
#  (3, 'CA', '93907'),
#  (3, 'CA', '95032'),
#  (3, 'CA', '90731'),
#  (3, 'CA', '94568'),
#  (3, 'CA', '92019'),
#  (3, 'CA', '91311'),
#  (3, 'CA', '93924'),
#  (3, 'CA', '95926'),
#  (3, 'CA', '95618'),
#  (3, 'CA', '94115'),
#  (3, 'CA', '95621'),
#  (3, 'CA', '95051'),
#  (3, 'CA', '91321'),
#  (3, 'CA', '93955'),
#  (3, 'CA', '94002'),
#  (3, 'CA', '90807'),
#  (3, 'CA', '95062'),
#  (3, 'CA', '94010'),
#  (3, 'CA', '92111'),
#  (3, 'CA', '95630'),
#  (3, 'CA', '94928'),
#  (3, 'CA', '92115'),
#  (3, 'CA', '95648'),
#  (3, 'CA', '92037'),
#  (3, 'CA', '93035'),
#  (3, 'CA', '94536'),
#  (3, 'CA', '90024'),
#  (3, 'CA', '91001'),
#  (3, 'CA', '95682'),
#  (3, 'CA', '93041'),
#  (3, 'CA', '95448'),
#  (3, 'CA', '91786'),
#  (3, 'CA', '92562'),
#  (3, 'CA', '94949'),
#  (3, 'CA', '94598'),
#  (3, 'CA', '91364'),
#  (3, 'CA', '93546'),
#  (3, 'CA', '92056'),
#  (3, 'CA', '93065'),
#  (3, 'CA', '92691'),
#  (3, 'CA', '94027'),
#  (3, 'CA', '92057'),
#  (3, 'CA', '92592'),
#  (3, 'CA', '91403'),
#  (3, 'CA', '91101'),
#  (3, 'CA', '94607'),
#  (3, 'CA', '92603'),
#  (3, 'CA', '92129'),
#  (3, 'CA', '94551'),
#  (3, 'CA', '95492'),
#  (3, 'CA', '94609'),
#  (3, 'CA', '92131'),
#  (3, 'CA', '93230'),
#  (3, 'CA', '95136'),
#  (3, 'CA', '92618'),
#  (3, 'CA', '90403'),
#  (3, 'CA', '94618'),
#  (3, 'CA', '93711'),
#  (3, 'CA', '94619'),
#  (3, 'CA', '92081'),
#  (3, 'CA', '95819'),
#  (3, 'CA', '92084'),
#  (3, 'CA', '91208'),
#  (3, 'CA', '94563'),
#  (3, 'CA', '90064'),
#  (3, 'CA', '92629'),
#  (3, 'CA', '90065'),
#  (3, 'CA', '92008'),
#  (3, 'CA', '94705'),
#  (3, 'CA', '92867'),
#  (2, 'CA', '95030'),
#  (2, 'CA', '91302'),
#  (2, 'CA', '95835'),
#  (2, 'CA', '94566'),
#  (2, 'CA', '92010'),
#  (2, 'CA', '92647'),
#  (2, 'CA', '93908'),
#  (2, 'CA', '94707'),
#  (2, 'CA', '95843'),
#  (2, 'CA', '93401'),
#  (2, 'CA', '94515'),
#  (2, 'CA', '92014'),
#  (2, 'CA', '92880'),
#  (2, 'CA', '95033'),
#  (2, 'CA', '93923'),
#  (2, 'CA', '92104'),
#  (2, 'CA', '93402'),
#  (2, 'CA', '92881'),
#  (2, 'CA', '94519'),
#  (2, 'CA', '92270'),
#  (2, 'CA', '90755'),
#  (2, 'CA', '92020'),
#  (2, 'CA', '95620'),
#  (2, 'CA', '94521'),
#  (2, 'CA', '90012'),
#  (2, 'CA', '91730'),
#  (2, 'CA', '92653'),
#  (2, 'CA', '93422'),
#  (2, 'CA', '93010'),
#  (2, 'CA', '94116'),
#  (2, 'CA', '92373'),
#  (2, 'CA', '95959'),
#  (2, 'CA', '94582'),
#  (2, 'CA', '94526'),
#  (2, 'CA', '92657'),
#  (2, 'CA', '94920'),
#  (2, 'CA', '92110'),
#  (2, 'CA', '93013'),
#  (2, 'CA', '90808'),
#  (2, 'CA', '93444'),
#  (2, 'CA', '94530'),
#  (2, 'CA', '95409'),
#  (2, 'CA', '95065'),
#  (2, 'CA', '95070'),
#  (2, 'CA', '91335'),
#  (2, 'CA', '92506'),
#  (2, 'CA', '94930'),
#  (2, 'CA', '90813'),
#  (2, 'CA', '94534'),
#  (2, 'CA', '92673'),
#  (2, 'CA', '91354'),
#  (2, 'CA', '94015'),
#  (2, 'CA', '94939'),
#  (2, 'CA', '96022'),
#  (2, 'CA', '95437'),
#  (2, 'CA', '95110'),
#  (2, 'CA', '91355'),
#  (2, 'CA', '90815'),
#  (2, 'CA', '95678'),
#  (2, 'CA', '93036'),
#  (2, 'CA', '94129'),
#  (2, 'CA', '95112'),
#  (2, 'CA', '94022'),
#  (2, 'CA', '92120'),
#  (2, 'CA', '94539'),
#  (2, 'CA', '94024'),
#  (2, 'CA', '93536'),
#  (2, 'CA', '90272'),
#  (2, 'CA', '92054'),
#  (2, 'CA', '93063'),
#  (2, 'CA', '94132'),
#  (2, 'CA', '92123'),
#  (2, 'CA', '95691'),
#  (2, 'CA', '95460'),
#  (2, 'CA', '90029'),
#  (2, 'CA', '94133'),
#  (2, 'CA', '92124'),
#  (2, 'CA', '94954'),
#  (2, 'CA', '92694'),
#  (2, 'CA', '94158'),
#  (2, 'CA', '91387'),
#  (2, 'CA', '94041'),
#  (2, 'CA', '95695'),
#  (2, 'CA', '94301'),
#  (2, 'CA', '95124'),
#  (2, 'CA', '94960'),
#  (2, 'CA', '96161'),
#  (2, 'CA', '93110'),
#  (2, 'CA', 'N/A'),
#  (2, 'CA', '91104'),
#  (2, 'CA', '92065'),
#  (2, 'CA', '95482'),
#  (2, 'CA', '91105'),
#  (2, 'CA', '94608'),
#  (2, 'CA', '92606'),
#  (2, 'CA', '91423'),
#  (2, 'CA', '91106'),
#  (2, 'CA', '94553'),
#  (2, 'CA', '92780'),
#  (2, 'CA', '95134'),
#  (2, 'CA', '94070'),
#  (2, 'CA', '94610'),
#  (2, 'CA', '90402'),
#  (2, 'CA', '90045'),
#  (2, 'CA', '92782'),
#  (2, 'CA', '95005'),
#  (2, 'CA', '92075'),
#  (2, 'CA', '91502'),
#  (2, 'CA', '95816'),
#  (2, 'CA', '91505'),
#  (2, 'CA', '95010'),
#  (2, 'CA', '93291'),
#  (2, 'CA', '94559'),
#  (2, 'CA', '91945'),
#  (2, 'CA', '94502'),
#  (2, 'CA', '92626'),
#  (2, 'CA', '94089'),
#  (2, 'CA', '91207'),
#  (2, 'CA', '90503'),
#  (2, 'CA', '92003'),
#  (2, 'CA', '91604'),
#  (2, 'CA', '92627'),
#  (2, 'CA', '93308'),
#  (2, 'CA', '92835'),
#  (2, 'CA', '94505'),
#  (2, 'CA', '95354'),
#  (2, 'CA', '91606'),
#  (2, 'CA', '90638'),
#  (2, 'CA', '93309'),
#  (2, 'CA', '94564'),
#  (2, 'CA', '91607'),
#  (2, 'CA', '90066'),
#  (2, 'CA', '94507'),
#  (1, 'CA', '91701'),
#  (1, 'CA', '92260'),
#  (1, 'CA', '92102'),
#  (1, 'CA', '93312'),
#  (1, 'CA', '90067'),
#  (1, 'CA', '92869'),
#  (1, 'CA', '95361'),
#  (1, 'CA', '95366'),
#  (1, 'CA', '91303'),
#  (1, 'CA', '92262'),
#  (1, 'CA', '95610'),
#  (1, 'CA', '92011'),
#  (1, 'CA', '92870'),
#  (1, 'CA', '94518'),
#  (1, 'CA', '95383'),
#  (1, 'CA', '91702'),
#  (1, 'CA', '92648'),
#  (1, 'CA', '92263'),
#  (1, 'CA', '94708'),
#  (1, 'CA', '95864'),
#  (1, 'CA', '90740'),
#  (1, 'CA', '94571'),
#  (1, 'CA', '90071'),
#  (1, 'CA', '91711'),
#  (1, 'CA', '94112'),
#  (1, 'CA', '95037'),
#  (1, 'CA', '94709'),
#  (1, 'CA', '92105'),
#  (1, 'CA', '93405'),
#  (1, 'CA', '94574'),
#  (1, 'CA', '90077'),
#  (1, 'CA', '94520'),
#  (1, 'CA', '90005'),
#  (1, 'CA', '91723'),
#  (1, 'CA', '92651'),
#  (1, 'CA', '95046'),
#  (1, 'CA', '91316'),
#  (1, 'CA', '92307'),
#  (1, 'CA', '95945'),
#  (1, 'CA', '93420'),
#  (1, 'CA', '94577'),
#  (1, 'CA', '92021'),
#  (1, 'CA', '95050'),
#  (1, 'CA', '92320'),
#  (1, 'CA', '93953'),
#  (1, 'CA', '95949'),
#  (1, 'CA', '90804'),
#  (1, 'CA', '94580'),
#  (1, 'CA', '90014'),
#  (1, 'CA', '91737'),
#  (1, 'CA', '90806'),
#  (1, 'CA', '93428'),
#  (1, 'CA', '95624'),
#  (1, 'CA', '92025'),
#  (1, 'CA', '95405'),
#  (1, 'CA', '90015'),
#  (1, 'CA', '91748'),
#  (1, 'CA', '95060'),
#  (1, 'CA', '91324'),
#  (1, 'CA', '92374'),
#  (1, 'CA', '95965'),
#  (1, 'CA', '93443'),
#  (1, 'CA', '95628'),
#  (1, 'CA', '90230'),
#  (1, 'CA', '94528'),
#  (1, 'CA', '90016'),
#  (1, 'CA', '91750'),
#  (1, 'CA', '91325'),
#  (1, 'CA', '92503'),
#  (1, 'CA', '94925'),
#  (1, 'CA', '96001'),
#  (1, 'CA', '94585'),
#  (1, 'CA', '92027'),
#  (1, 'CA', '90017'),
#  (1, 'CA', '91755'),
#  (1, 'CA', '92663'),
#  (1, 'CA', '91326'),
#  (1, 'CA', '92504'),
#  (1, 'CA', '94011'),
#  (1, 'CA', '96002'),
#  (1, 'CA', '90810'),
#  (1, 'CA', '93446'),
#  (1, 'CA', '94588'),
#  (1, 'CA', '95633'),
#  (1, 'CA', '90242'),
#  (1, 'CA', '92028'),
#  (1, 'CA', '93021'),
#  (1, 'CA', '94531'),
#  (1, 'CA', '95425'),
#  (1, 'CA', '90019'),
#  (1, 'CA', '91764'),
#  (1, 'CA', '94122'),
#  (1, 'CA', '94014'),
#  (1, 'CA', '96003'),
#  (1, 'CA', '93447'),
#  (1, 'CA', '94590'),
#  (1, 'CA', '90247'),
#  (1, 'CA', '95436'),
#  (1, 'CA', '90020'),
#  (1, 'CA', '91770'),
#  (1, 'CA', '95076'),
#  (1, 'CA', '92516'),
#  (1, 'CA', '90814'),
#  (1, 'CA', '93452'),
#  (1, 'CA', '94591'),
#  (1, 'CA', '95650'),
#  (1, 'CA', '94595'),
#  (1, 'CA', '95677'),
#  (1, 'CA', '92038'),
#  (1, 'CA', '91775'),
#  (1, 'CA', '92675'),
#  (1, 'CA', '92545'),
#  (1, 'CA', '94018'),
#  (1, 'CA', '96067'),
#  (1, 'CA', '92118'),
#  (1, 'CA', '93458'),
#  (1, 'CA', '92119'),
#  (1, 'CA', '93463'),
#  (1, 'CA', '94596'),
#  (1, 'CA', '92040'),
#  (1, 'CA', '94538'),
#  (1, 'CA', '95442'),
#  (1, 'CA', '91776'),
#  (1, 'CA', '91356'),
#  (1, 'CA', '92549'),
#  (1, 'CA', '94947'),
#  (1, 'CA', '96073'),
#  (1, 'CA', '91006'),
#  (1, 'CA', '93534'),
#  (1, 'CA', '92046'),
#  (1, 'CA', '92683'),
#  (1, 'CA', '95113'),
#  (1, 'CA', '91361'),
#  (1, 'CA', '96104'),
#  (1, 'CA', '91011'),
#  (1, 'CA', '95688'),
#  (1, 'CA', '94542'),
#  (1, 'CA', '95457'),
#  (1, 'CA', '91789'),
#  (1, 'CA', '92688'),
#  (1, 'CA', '95116'),
#  (1, 'CA', '92586'),
#  (1, 'CA', '94951'),
#  (1, 'CA', '96107'),
#  (1, 'CA', '91016'),
#  (1, 'CA', '94599'),
#  (1, 'CA', '94544'),
#  (1, 'CA', '91791'),
#  (1, 'CA', '95119'),
#  (1, 'CA', '92590'),
#  (1, 'CA', '96141'),
#  (1, 'CA', '93549'),
#  (1, 'CA', '95692'),
#  (1, 'CA', '94545'),
#  (1, 'CA', '95465'),
#  (1, 'CA', '90031'),
#  (1, 'CA', '91801'),
#  (1, 'CA', '92692'),
#  (1, 'CA', '94134'),
#  (1, 'CA', '95120'),
#  (1, 'CA', '91377'),
#  (1, 'CA', '96145'),
#  (1, 'CA', '91041'),
#  (1, 'CA', '93550'),
#  (1, 'CA', '95694'),
#  (1, 'CA', '92058'),
#  (1, 'CA', '94546'),
#  (1, 'CA', '95470'),
#  (1, 'CA', '91901'),
#  (1, 'CA', '95123'),
#  (1, 'CA', '92593'),
#  (1, 'CA', '94955'),
#  (1, 'CA', '96151'),
#  (1, 'CA', '91042'),
#  (1, 'CA', '92127'),
#  (1, 'CA', '94605'),
#  (1, 'CA', '90290'),
#  (1, 'CA', '92059'),
#  (1, 'CA', '93108'),
#  (1, 'CA', '94547'),
#  (1, 'CA', '91902'),
#  (1, 'CA', '92701'),
#  (1, 'CA', '92595'),
#  (1, 'CA', '94043'),
#  (1, 'CA', '93562'),
#  (1, 'CA', '94606'),
#  (1, 'CA', '95722'),
#  (1, 'CA', '91908'),
#  (1, 'CA', '92705'),
#  (1, 'CA', '94303'),
#  (1, 'CA', '91405'),
#  (1, 'CA', '92602'),
#  (1, 'CA', '94044'),
#  (1, 'CA', '94963'),
#  (1, 'CA', '93611'),
#  (1, 'CA', '95746'),
#  (1, 'CA', '93117'),
#  (1, 'CA', '90041'),
#  (1, 'CA', '91910'),
#  (1, 'CA', '92707'),
#  (1, 'CA', '94304'),
#  (1, 'CA', '95128'),
#  (1, 'CA', '93619'),
#  (1, 'CA', '95747'),
#  (1, 'CA', '90293'),
#  (1, 'CA', '93150'),
#  (1, 'CA', '90042'),
#  (1, 'CA', '91913'),
#  (1, 'CA', '92708'),
#  (1, 'CA', '95132'),
#  (1, 'CA', '91411'),
#  (1, 'CA', '94966'),
#  (1, 'CA', '92610'),
#  (1, 'CA', '94063'),
#  (1, 'CA', '94970'),
#  (1, 'CA', '93637'),
#  (1, 'CA', '90401'),
#  (1, 'CA', '93225'),
#  (1, 'CA', '95501'),
#  (1, 'CA', '90043'),
#  (1, 'CA', '91921'),
#  (1, 'CA', '94402'),
#  (1, 'CA', '91436'),
#  (1, 'CA', '91201'),
#  (1, 'CA', '93643'),
#  (1, 'CA', '95765'),
#  (1, 'CA', '92072'),
#  (1, 'CA', '94555'),
#  (1, 'CA', '95503'),
#  (1, 'CA', '91931'),
#  (1, 'CA', '91501'),
#  (1, 'CA', '94080'),
#  (1, 'CA', '91203'),
#  (1, 'CA', '92143'),
#  (1, 'CA', '93654'),
#  (1, 'CA', '95811'),
#  (1, 'CA', '93243'),
#  (1, 'CA', '94556'),
#  (1, 'CA', '95519'),
#  (1, 'CA', '92806'),
#  (1, 'CA', '94404'),
#  (1, 'CA', '95138'),
#  (1, 'CA', '92620'),
#  (1, 'CA', '94086'),
#  (1, 'CA', '91204'),
#  (1, 'CA', '92163'),
#  (1, 'CA', '93710'),
#  (1, 'CA', '93257'),
#  (1, 'CA', '95536'),
#  (1, 'CA', '90048'),
#  (1, 'CA', '92807'),
#  (1, 'CA', '95212'),
#  (1, 'CA', '92625'),
#  (1, 'CA', '94087'),
#  (1, 'CA', '91205'),
#  (1, 'CA', '95540'),
#  (1, 'CA', '92821'),
#  (1, 'CA', '95227'),
#  (1, 'CA', '91602'),
#  (1, 'CA', '92223'),
#  (1, 'CA', '93720'),
#  (1, 'CA', '94702'),
#  (1, 'CA', '93292'),
#  (1, 'CA', '94560'),
#  (1, 'CA', '95570'),
#  (1, 'CA', '90051'),
#  (1, 'CA', '92831'),
#  (1, 'CA', '94503'),
#  (1, 'CA', '95236'),
#  (1, 'CA', '95018'),
#  (1, 'CA', '92232'),
#  (1, 'CA', '93722'),
#  (1, 'CA', '95831'),
#  (1, 'CA', '90504'),
#  (1, 'CA', '92091'),
#  (1, 'CA', '95602'),
#  (1, 'CA', '92007'),
#  (1, 'CA', '94102'),
#  (1, 'CA', '95020'),
#  (1, 'CA', '91214'),
#  (1, 'CA', '92247'),
#  (1, 'CA', '93726'),
#  (1, 'CA', '94704'),
#  (1, 'CA', '95833'),
#  (1, 'CA', '92092'),
#  (1, 'CA', '95603'),
#  (1, 'CA', '92865'),
#  (1, 'CA', '95355'),
#  (1, 'CA', '92637'),
#  (1, 'CA', '94103'),
#  (1, 'CA', '95023'),
#  (1, 'CA', '92253'),
#  (1, 'CA', '93730'),
#  (1, 'CA', '95834'),
#  (1, 'CA', '90704'),
#  (1, 'CA', '93311'),
#  (1, 'CA', '94565'),
#  (1, 'CA', '95605'),
#  (1, 'CA', '95356'),
#  (10, 'CO', '80304'),
#  (9, 'CO', '80210'),
#  (7, 'CO', '80526'),
#  (7, 'CO', '80303'),
#  (6, 'CO', '80220'),
#  (6, 'CO', '80403'),
#  (5, 'CO', '80205'),
#  (5, 'CO', '80206'),
#  (5, 'CO', '80227'),
#  (5, 'CO', '80126'),
#  (5, 'CO', '80401'),
#  (4, 'CO', '80020'),
#  (4, 'CO', '80439'),
#  (4, 'CO', '80021'),
#  (4, 'CO', '80026'),
#  (4, 'CO', '80211'),
#  (4, 'CO', '80922'),
#  (4, 'CO', '80521'),
#  (4, 'CO', '80111'),
#  (4, 'CO', '80237'),
#  (4, 'CO', '81601'),
#  (4, 'CO', '81620'),
#  (4, 'CO', '80127'),
#  (4, 'CO', '80128'),
#  (4, 'CO', '80132'),
#  (4, 'CO', '80134'),
#  (3, 'CO', '80904'),
#  (3, 'CO', '80906'),
#  (3, 'CO', '80212'),
#  (3, 'CO', '80503'),
#  (3, 'CO', '80525'),
#  (3, 'CO', '80302'),
#  (3, 'CO', '80014'),
#  (3, 'CO', '80015'),
#  (2, 'CO', '80908'),
#  (2, 'CO', '80027'),
#  (2, 'CO', '80917'),
#  (2, 'CO', '80918'),
#  (2, 'CO', '80214'),
#  (2, 'CO', '80919'),
#  (2, 'CO', '80923'),
#  (2, 'CO', '80218'),
#  (2, 'CO', '80222'),
#  (2, 'CO', '80524'),
#  (2, 'CO', '80112'),
#  (2, 'CO', '80113'),
#  (2, 'CO', '80120'),
#  (2, 'CO', '81301'),
#  (2, 'CO', '80234'),
#  (2, 'CO', '81501'),
#  (2, 'CO', '80238'),
#  (2, 'CO', '80004'),
#  (2, 'CO', '81611'),
#  (2, 'CO', '80247'),
#  (2, 'CO', '80005'),
#  (2, 'CO', '80301'),
#  (2, 'CO', '81623'),
#  (2, 'CO', '80129'),
#  (2, 'CO', '80138'),
#  (2, 'CO', '80827'),
#  (2, 'CO', '80203'),
#  (1, 'CO', '80016'),
#  (1, 'CO', '80829'),
#  (1, 'CO', '80430'),
#  (1, 'CO', '80204'),
#  (1, 'CO', '80864'),
#  (1, 'CO', '80465'),
#  (1, 'CO', '80207'),
#  (1, 'CO', '80022'),
#  (1, 'CO', '80466'),
#  (1, 'CO', '80209'),
#  (1, 'CO', '80023'),
#  (1, 'CO', '80487'),
#  (1, 'CO', '80911'),
#  (1, 'CO', '80488'),
#  (1, 'CO', '80498'),
#  (1, 'CO', '80031'),
#  (1, 'CO', '80501'),
#  (1, 'CO', '80033'),
#  (1, 'CO', '80215'),
#  (1, 'CO', '80104'),
#  (1, 'CO', '80504'),
#  (1, 'CO', '80216'),
#  (1, 'CO', '80106'),
#  (1, 'CO', '80516'),
#  (1, 'CO', '80107'),
#  (1, 'CO', '80962'),
#  (1, 'CO', '80517'),
#  (1, 'CO', '80108'),
#  (1, 'CO', '81007'),
#  (1, 'CO', '80109'),
#  (1, 'CO', '81131'),
#  (1, 'CO', '80223'),
#  (1, 'CO', '81201'),
#  (1, 'CO', '80226'),
#  (1, 'CO', '81235'),
#  (1, 'CO', '81236'),
#  (1, 'CO', '80527'),
#  (1, 'CO', '80228'),
#  (1, 'CO', '80116'),
#  (1, 'CO', '81252'),
#  (1, 'CO', '80528'),
#  (1, 'CO', '80230'),
#  (1, 'CO', '80534'),
#  (1, 'CO', '80233'),
#  (1, 'CO', '80121'),
#  (1, 'CO', '81403'),
#  (1, 'CO', '80537'),
#  (1, 'CO', '80122'),
#  (1, 'CO', '80540'),
#  (1, 'CO', '80123'),
#  (1, 'CO', '80000'),
#  (1, 'CO', '81507'),
#  (1, 'CO', '80542'),
#  (1, 'CO', '80124'),
#  (1, 'CO', '80002'),
#  (1, 'CO', '80547'),
#  (1, 'CO', '80602'),
#  (1, 'CO', '81621'),
#  (1, 'CO', '80631'),
#  (1, 'CO', '80010'),
#  (1, 'CO', '80634'),
#  (1, 'CO', '80011'),
#  (1, 'CO', '81625'),
#  (1, 'CO', '80643'),
#  (1, 'CO', '80012'),
#  (1, 'CO', '81639'),
#  (1, 'CO', '80644'),
#  (1, 'CO', '80308'),
#  (1, 'CO', '80013'),
#  (1, 'CO', '81652'),
#  (1, 'CO', '80808'),
#  (1, 'CO', '80813'),
#  (1, 'CO', '80202'),
#  (1, 'CO', '80422'),
#  (8, 'CT', '6880'),
#  (6, 'CT', '6824'),
#  (6, 'CT', '6840'),
#  (5, 'CT', '6614'),
#  (5, 'CT', '6820'),
#  (4, 'CT', '6107'),
#  (4, 'CT', '6109'),
#  (4, 'CT', '6902'),
#  (3, 'CT', '6410'),
#  (3, 'CT', '6851'),
#  (3, 'CT', '6484'),
#  (3, 'CT', '6117'),
#  (3, 'CT', '6489'),
#  (3, 'CT', '6877'),
#  (3, 'CT', '6517'),
#  (3, 'CT', '6371'),
#  (3, 'CT', '6903'),
#  (3, 'CT', '6905'),
#  (2, 'CT', '6612'),
#  (2, 'CT', '6405'),
#  (2, 'CT', '6033'),
#  (2, 'CT', '6415'),
#  (2, 'CT', '6035'),
#  (2, 'CT', '6416'),
#  (2, 'CT', '6762'),
#  (2, 'CT', '6040'),
#  (2, 'CT', '6776'),
#  (2, 'CT', '6422'),
#  (2, 'CT', '6777'),
#  (2, 'CT', '6798'),
#  (2, 'CT', '6073'),
#  (2, 'CT', '6811'),
#  (2, 'CT', '6830'),
#  (2, 'CT', '6478'),
#  (2, 'CT', '6480'),
#  (2, 'CT', '6853'),
#  (2, 'CT', '6854'),
#  (2, 'CT', '6511'),
#  (2, 'CT', '6512'),
#  ...]

# %% [markdown]
# **Question 7: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code in the United States *that have at least 5 users*, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state/ZIP code combination should be AZ/86303).**

# %%
# %%sql
# SELECT COUNT(DISTINCT user_guid) AS num_user_guid,state,zip
# FROM users
# WHERE country="US"
# GROUP BY state,zip
# HAVING num_user_guid>=5
# ORDER BY state,num_user_guid DESC;
# Out:
# 285 rows affected.
# [(14, 'AZ', '86303'),
#  (6, 'AZ', '85718'),
#  (5, 'AZ', '85260'),
#  (5, 'AZ', '85711'),
#  (5, 'AZ', '85749'),
#  (5, 'AZ', '85253'),
#  (5, 'AZ', '85254'),
#  (16, 'CA', '92107'),
#  (13, 'CA', '90046'),
#  (12, 'CA', '94107'),
#  (12, 'CA', '92130'),
#  (10, 'CA', '94110'),
#  (10, 'CA', '92024'),
#  (9, 'CA', '94114'),
#  (9, 'CA', '94941'),
#  (9, 'CA', '94025'),
#  (9, 'CA', '94611'),
#  (8, 'CA', '90068'),
#  (8, 'CA', '90069'),
#  (8, 'CA', '94131'),
#  (8, 'CA', '92064'),
#  (8, 'CA', '90049'),
#  (7, 'CA', '90803'),
#  (7, 'CA', '93003'),
#  (7, 'CA', '94117'),
#  (7, 'CA', '94121'),
#  (7, 'CA', '90266'),
#  (7, 'CA', '94602'),
#  (7, 'CA', '90278'),
#  (7, 'CA', '90291'),
#  (7, 'CA', '90292'),
#  (6, 'CA', '92103'),
#  (6, 'CA', '94901'),
#  (6, 'CA', '94903'),
#  (6, 'CA', '92672'),
#  (6, 'CA', '94123'),
#  (6, 'CA', '90274'),
#  (6, 'CA', '94952'),
#  (6, 'CA', '90277'),
#  (6, 'CA', '90036'),
#  (6, 'CA', '94549'),
#  (6, 'CA', '90039'),
#  (6, 'CA', '94061'),
#  (6, 'CA', '95762'),
#  (6, 'CA', '92071'),
#  (6, 'CA', '95008'),
#  (6, 'CA', '95014'),
#  (6, 'CA', '91301'),
#  (5, 'CA', '94706'),
#  (5, 'CA', '94510'),
#  (5, 'CA', '94109'),
#  (5, 'CA', '93940'),
#  (5, 'CA', '92106'),
#  (5, 'CA', '90210'),
#  (5, 'CA', '94904'),
#  (5, 'CA', '93012'),
#  (5, 'CA', '94118'),
#  (5, 'CA', '90232'),
#  (5, 'CA', '93023'),
#  (5, 'CA', '90025'),
#  (5, 'CA', '94597'),
#  (5, 'CA', '92122'),
#  (5, 'CA', '94040'),
#  (5, 'CA', '93105'),
#  (5, 'CA', '95476'),
#  (5, 'CA', '94550'),
#  (5, 'CA', '91406'),
#  (5, 'CA', '95003'),
#  (5, 'CA', '92211'),
#  (5, 'CA', '95818'),
#  (5, 'CA', '90405'),
#  (5, 'CA', '92101'),
#  (5, 'CA', '92009'),
#  (10, 'CO', '80304'),
#  (9, 'CO', '80210'),
#  (7, 'CO', '80526'),
#  (7, 'CO', '80303'),
#  (6, 'CO', '80220'),
#  (6, 'CO', '80403'),
#  (5, 'CO', '80205'),
#  (5, 'CO', '80206'),
#  (5, 'CO', '80227'),
#  (5, 'CO', '80126'),
#  (5, 'CO', '80401'),
#  (8, 'CT', '6880'),
#  (6, 'CT', '6824'),
#  (6, 'CT', '6840'),
#  (5, 'CT', '6614'),
#  (5, 'CT', '6820'),
#  (14, 'DC', '20009'),
#  (8, 'DC', '20002'),
#  (8, 'DC', '20007'),
#  (7, 'DC', '20001'),
#  (7, 'DC', '20016'),
#  (6, 'DC', '20005'),
#  (6, 'DC', '20011'),
#  (5, 'DC', '20003'),
#  (7, 'DE', '19958'),
#  (6, 'FL', '33418'),
#  (6, 'FL', '33647'),
#  (6, 'FL', '32312'),
#  (5, 'FL', '33156'),
#  (5, 'FL', '32751'),
#  (5, 'FL', '32765'),
#  (7, 'GA', '30305'),
#  (7, 'GA', '30004'),
#  (6, 'GA', '30345'),
#  (5, 'GA', '30067'),
#  (5, 'GA', '30308'),
#  (5, 'GA', '30316'),
#  (5, 'GA', '30328'),
#  (8, 'HI', '96734'),
#  (9, 'ID', '83702'),
#  (18, 'IL', '60614'),
#  (11, 'IL', '60654'),
#  (9, 'IL', '60640'),
#  (9, 'IL', '60657'),
#  (8, 'IL', '60613'),
#  (7, 'IL', '60660'),
#  (7, 'IL', '60610'),
#  (6, 'IL', '60647'),
#  (6, 'IL', '60618'),
#  (5, 'IL', '60642'),
#  (5, 'IL', '60093'),
#  (5, 'IL', '60626'),
#  (6, 'IN', '47401'),
#  (6, 'KS', '66062'),
#  (8, 'LA', '70115'),
#  (6, 'LA', '70118'),
#  (8, 'MA', '2127'),
#  (6, 'MA', '2129'),
#  (5, 'MA', '2116'),
#  (5, 'MA', '2130'),
#  (5, 'MA', '2135'),
#  (5, 'MA', '2143'),
#  (5, 'MA', '2472'),
#  (8, 'MD', '20854'),
#  (7, 'MD', '20817'),
#  (7, 'MD', '20910'),
#  (6, 'MD', '21286'),
#  (6, 'MD', '20878'),
#  (5, 'MD', '20852'),
#  (5, 'MD', '21228'),
#  (5, 'MD', '21230'),
#  (5, 'MD', '20895'),
#  (8, 'MI', '48103'),
#  (6, 'MN', '55426'),
#  (6, 'MO', '63139'),
#  (5, 'MO', '63122'),
#  (5, 'MT', '59715'),
#  (83, 'N/A', 'N/A'),
#  (32, 'NC', '27701'),
#  (26, 'NC', '27705'),
#  (17, 'NC', '27516'),
#  (17, 'NC', '27707'),
#  (11, 'NC', '27517'),
#  (11, 'NC', '27613'),
#  (11, 'NC', '27615'),
#  (10, 'NC', '27713'),
#  (9, 'NC', '27514'),
#  (9, 'NC', '27617'),
#  (9, 'NC', '27278'),
#  (9, 'NC', '27539'),
#  (7, 'NC', '27608'),
#  (7, 'NC', '27513'),
#  (7, 'NC', '27609'),
#  (7, 'NC', '27614'),
#  (7, 'NC', '27519'),
#  (6, 'NC', '28270'),
#  (6, 'NC', '27587'),
#  (6, 'NC', '27410'),
#  (6, 'NC', '27603'),
#  (6, 'NC', '27607'),
#  (6, 'NC', '28374'),
#  (6, 'NC', '27104'),
#  (6, 'NC', '27612'),
#  (6, 'NC', '28787'),
#  (5, 'NC', '27502'),
#  (5, 'NC', '27606'),
#  (5, 'NC', '28205'),
#  (5, 'NC', '28226'),
#  (8, 'NJ', '7030'),
#  (7, 'NJ', '7302'),
#  (5, 'NJ', '8540'),
#  (6, 'NM', '87111'),
#  (5, 'NV', '89511'),
#  (14, 'NY', '10003'),
#  (13, 'NY', '10023'),
#  (13, 'NY', '10024'),
#  (12, 'NY', '11201'),
#  (12, 'NY', '10025'),
#  (11, 'NY', '10028'),
#  (10, 'NY', '10016'),
#  (9, 'NY', '10011'),
#  (9, 'NY', '10019'),
#  (8, 'NY', '14850'),
#  (8, 'NY', '10014'),
#  (8, 'NY', '10021'),
#  (8, 'NY', '11238'),
#  (7, 'NY', '11249'),
#  (6, 'NY', '10128'),
#  (6, 'NY', '10583'),
#  (6, 'NY', '10012'),
#  (6, 'NY', '10013'),
#  (6, 'NY', '11217'),
#  (5, 'NY', '11105'),
#  (5, 'NY', '10075'),
#  (5, 'NY', '11209'),
#  (5, 'NY', '11211'),
#  (5, 'NY', '11215'),
#  (5, 'NY', '10708'),
#  (5, 'NY', '11222'),
#  (5, 'NY', '10022'),
#  (8, 'OH', '43214'),
#  (5, 'OH', '43235'),
#  (5, 'OH', '43068'),
#  (5, 'OH', '45243'),
#  (5, 'OH', '45040'),
#  (5, 'OH', '44149'),
#  (5, 'OK', '73013'),
#  (8, 'OR', '97229'),
#  (7, 'OR', '97212'),
#  (5, 'OR', '97405'),
#  (5, 'OR', '97206'),
#  (5, 'OR', '97215'),
#  (5, 'OR', '97702'),
#  (6, 'PA', '19087'),
#  (6, 'PA', '19460'),
#  (6, 'PA', '19147'),
#  (5, 'PA', '15101'),
#  (5, 'PA', '15237'),
#  (14, 'SC', '29303'),
#  (13, 'SC', '29464'),
#  (5, 'SC', '29205'),
#  (5, 'SC', '29407'),
#  (5, 'SC', '29707'),
#  (7, 'TN', '37205'),
#  (6, 'TN', '37027'),
#  (6, 'TN', '37067'),
#  (8, 'TX', '77008'),
#  (8, 'TX', '78745'),
#  (8, 'TX', '78750'),
#  (7, 'TX', '78703'),
#  (7, 'TX', '77007'),
#  (6, 'TX', '78704'),
#  (6, 'TX', '78757'),
#  (6, 'TX', '77584'),
#  (5, 'TX', '77381'),
#  (5, 'TX', '77382'),
#  (5, 'TX', '75023'),
#  (5, 'TX', '75025'),
#  (5, 'TX', '75219'),
#  (5, 'TX', '76712'),
#  (5, 'TX', '78613'),
#  (5, 'TX', '77006'),
#  (5, 'TX', '75248'),
#  (5, 'TX', '78748'),
#  (6, 'UT', '84098'),
#  (9, 'VA', '22201'),
#  (9, 'VA', '20191'),
#  (8, 'VA', '22314'),
#  (7, 'VA', '22903'),
#  (7, 'VA', '22043'),
#  (7, 'VA', '20147'),
#  (6, 'VA', '22101'),
#  (6, 'VA', '20120'),
#  (6, 'VA', '22304'),
#  (5, 'VA', '23462'),
#  (5, 'VA', '22301'),
#  (5, 'VA', '22902'),
#  (9, 'WA', '98103'),
#  (7, 'WA', '98118'),
#  (7, 'WA', '98122'),
#  (7, 'WA', '98225'),
#  (7, 'WA', '98102'),
#  (6, 'WA', '98045'),
#  (6, 'WA', '98052'),
#  (6, 'WA', '98199'),
#  (6, 'WA', '98074'),
#  (6, 'WA', '98033'),
#  (6, 'WA', '98115'),
#  (5, 'WA', '98072'),
#  (5, 'WA', '98106'),
#  (5, 'WA', '98110'),
#  (5, 'WI', '53213')]

# %% [markdown]
# <mark>**Be sure to watch the next video before beginning Exercise 6, the next set of MySQL exercises</mark>,** **and feel free to practice any other queries you wish below!**
